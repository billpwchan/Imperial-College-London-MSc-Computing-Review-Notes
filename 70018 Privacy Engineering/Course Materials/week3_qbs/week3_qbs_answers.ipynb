# %% [markdown]
# # Exercise session 3: Query-based systems
#
# In this session, you will be given access to a private dataset through queries. You will be confronted to different noise addition mechanisms that attempt to preserve the privacy of people in the datasets, and will develop attacks to obtain private information on users.

# %% [markdown]
# ## The dataset
#
# This dataset containst records for 32561 people from a census. The columns of this dataset are:
# `age`, `workclass`, `fnlwgt`, `education`, `education-num`, `marital-status`, `occupation`, `relationship`, `race`, `sex`, `capital-gain`, `capital-loss`, `hours-per-week`, `native-country`, `salaryclass`. All of the columns are categorical, with values replaced by integers.
#
# This dataset is hosted on a server (whose IP will be given to you). The different data protection mechanisms are hosted available on two different ports. The queries that you are allowed to send belong to a subset of SQL:
#
# $$\texttt{condition} \ \ \text{and} \ \ \ldots \ \ \text{and} \ \ \texttt{condition}$$
#
# where `condition := columnname '<'|'>'|'<>'|'='|'<='|'>=' value`, and `value` is either an integer or an arithmetic expression that evaluates to an integer (e.g. `(2*2)`). Each of these queries returns the _count_ of users who satisfy all conditions in the query.
#
# In this notebook, you will try and find the `salaryclass` of some users,  using only queries. For simplicity, `salaryclass` is a binary attribute, where 0 corresponds to standard income and 1 is higher income.

# %%
import socket
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def remote_query(query, host, port):
    '''This function uses a very simple socket protocol to send 
       queries to the database system.'''
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.connect((host, port))
        s.sendall(query.encode('utf-8'))
        response = s.recv(1024).decode('utf-8')
        if response.startswith('ERROR '):
            raise Exception(response[6:])
    return eval(response)

# %% [markdown]
# The user you are asked to "attack" (let's call this user Alex), has the following attributes:

# %% [raw]
# age                  39
# workclass             7
# education             9
# education_num        13
# marital_status        4
# occupation            1
# relationship          1
# race                  4
# sex                   1
# capital_gain       2174
# capital_loss          0
# hours_per_week       40
# native_country       39
# salaryclass           ???

# %%
# Here are the attributes in Python form ;-)

Alex = { 'age':            39,
         'workclass':       7,
         'education':       9,
         'education_num':  13,
         'marital_status':  4,
         'occupation':      1,
         'relationship':    1,
         'race':            4,
         'sex':             1,
         'capital_gain': 2174,
         'capital_loss':    0,
         'hours_per_week': 40,
         'native_country': 39 }

# %% [markdown]
# These attributes will constitute your _background knowledge_ on the victim.

# %% [markdown]
# ## Exercise 1: Two simple mechanisms
#
# In this exercise, you will break two simple mechanisms: noise addition, and query set size restriction. Each mechanism requires a different attack. Then, we will combine these mechanisms, and show that (at least in this case) they do no effectively protect the sensitive information.
#
# All of these queries will be sent to the same server, whose IP will be provided by the TA. The first character of each query will specify which mechanism to use (but we have already taken care of this by defining convenient functions for you to use).

# %%
HOST  = "146.169.41.52"
PORT1 = 42420

# %% [markdown]
# ### Exercise 1a | Noise addition
#
# Firstly, you will interact with a very simple privacy mechanism, noise addition: the query-based system adds a noise $N \sim \mathcal{N}(0, 5)$ to the query's response. This noise is independent for each query.
#
# The following code defines the `query_1a` function that queries this specific system.

# %%
# you can use a direct call to `query_1a("your query")` for exercise 1.a
query_1a = lambda query: remote_query('a'+query, HOST, PORT1)

# %% [markdown]
# **Step 1:** Execute the following cell several times to see how the mechanism works. Feel free to change the query.

# %%
query_1a('age = 32 and sex = 1')
# Out:
# 571.080233122161

# %% [markdown]
# Since all you have access to are `COUNT` queries, you can't directly query the system to ask for Alex's `salaryclass`. There is a workaround, however: you can count the number of users who are Alex, _and_ have `salaryclass = 1`.
#
# **Step 2 _(action required)_**: Write and perform a query that targets specifically Alex and tests for `salaryclass = 1`. Is the result informative?
#
# _Your code should define a `query` variable._

# %%
# YOUR CODE HERE
query = '' # YOUR QUERY HERE

# ANSWER
query = ' and '.join('%s = %s' % x for x in Alex.items())
query += ' and salaryclass = 1'

# WHAT HAPPENS WHEN YOU QUERY IT?
print( query_1a(query) )
# Out:
# -3.9048387115905068

# %% [markdown]
# As you learned in the class, such a simple mechanism falls to simple _averaging attacks_. By the central limit theorem, repeating the query several times and taking the average reduces the variance of the noise, thus converging to the true answer.
#
# **Step 3 _(action required)_**: Given the distribution of the noise, propose a simple criterion to determine Alex's value, given the noisy samples. Compute how many queries you would need to have an error probability of less than 5%. This is a paper-and-pencil exercise.

# %% [markdown]
# _Your answer here._
#
# `SAMPLE ANSWER`
#
# Let's start with some notations. Let $b \in \{0,1\}$ the true value for Alex. Each sample is thus $X_i = b + N_i \sim \mathcal{N}(b,5)$. The test we propose to use, if given $n$ results $x_i$, is to estimate Alex's value as $1$ if $\frac{1}{n} \sum_{i=1}^n x_i \geq \frac{1}{2}$ (one can show this is the maximum likelihood estimator). Denote by $\hat{B}$ this estimate. We also denote $Y = \frac{1}{n} \sum_{i=1}^n N_i \sim \mathcal{N}(0, \frac{5}{n})$, the sum of all noise. This implies that $\hat{B}$ is 1 if $b + Y \geq 1/2$ and is 0 otherwise.
#
# There are two possible errors: predicting 1 for a 0, and vice versa:
# 1. $P[\hat{B} = 1~|~b=0] = P[Y \geq 1/2]$
# 2. $P[\hat{B} = 0~|~b=1] = P[1 + Y \leq 1/2] = P[Y \leq -1/2]$
#
# $Y$ is normally distributed, so by symmetry of the Gaussian these two errors are the same.
#
# We define "error" to mean that the prediction we make is different from the true value $b$. This means:
# $$P[error] = P\left[\hat{B} = 0, b = 1\right] + P\left[\hat{B} = 1, b = 0\right]$$
#
# This means that the probability of error can be written as follows (independently of the probability distribution of $b$):
# $$P[error] = P[\hat{B} = 1~|~b=0] \cdot P[b=0] + P[\hat{B} = 0~|~b=1] \cdot P[b=1] = P[Y \geq 1/2] \cdot (P[b=0] + P[b=1]) = P[Y \geq 1/2]$$
#
# Finally, we impose that this probability is less than 5% (denote $Z \sim \mathcal{N}(0,1)$ the standard normal distribution):
# $$P[Y \geq 1/2] = P[Z \geq \frac{1}{2 \sqrt{5/n}}] \leq 0.05$$
#
# Using the CDF of the Gaussian, we find the following contraint on $n$:
# $$\frac{\sqrt{n}}{2 \sqrt{5}} \geq z_{0.95} = 1.96,$$
# where $z_{0.95}$ is the 95th percentile of the standard normal distribution.
#
# And thus $n \geq 4 \cdot 1.96^2 \cdot 5 = 76.83$. Hence, **77 queries are enough**.

# %% [markdown]
# **Step 4 _(action required)_**: Perform the attack, using the `query` defined in step 2 and the number of queries you found in step 3.

# %%
# YOUR CODE HERE

# ANSWER
samples = []
for x in range( 77 ):
    samples.append(query_1a(query))

average = np.mean(samples)
decision = average >= 0.5

print('Samples collected:', samples)
print('Average:', average)
print("Alex's value is likely to be", int(decision))
# Out:
# Samples collected: [0.23201370544411057, -0.3015259117498421, -0.7898421997883777, -3.424961825077621, 4.953804656218172, 0.7720031376083756, -4.316016092247198, -1.3463533397882264, -0.5945770784526034, 0.39004590947729834, 0.1972707587689222, -2.518205463121084, 0.5509251775375861, -3.280021324305288, -4.917168370718214, 0.13178283963679424, 2.3049616230990977, 3.8817133507045942, 1.3437758304353806, -1.4686301505858737, 0.7681679052013052, -0.2658627364568269, -0.6017648779634516, 2.4262394692023235, 1.6548385019286274, -0.12971759658284038, -4.050078583968898, -3.6438289767780474, 3.7925478679854545, -0.9365383906513686, 0.8861672451414787, 1.326755100410307, -3.32294976065766, -2.3388721692006866, -1.4957859340659798, -3.85657558802101, -0.427986176964712, -2.012460053143236, 0.8668764252229783, 4.6900277098710905, 0.2512033586130026, 4.782554672325066, -0.0745019956869695, 1.528818912084902, -0.47023269004025753, 1.313593962612844, -3.4242734660853804, 0.8204571777999554, 4.5292536439411615, 0.927615515020691, 2.071956197198127, -1.2164426029781117, 1.1109407153348434, -2.1243041165355034, 3.9120908872786035, -2.204146804607237, -3.7435657017446986, 2.9998595639817887, -2.625588340319116, -0.3762281449819101, -1.0217568382820772, -1.1416781269714207, -3.256235145881532, 2.3745506861295107, 0.6417338952957586, 0.7626019660720771, -4.067762292819445, 1.5710928130181385, 5.8358903264018025, 4.031118349126462, 0.1681877647465509, 1.4095594582445992, -0.74614326561312, -2.7830612451042827, -4.0682882465418695, 0.5759477806476696, -0.4727263558299529]
# Average: -0.0917884820849933
# Alex's value is likely to be 0

# %% [markdown]
# ### Exercise 1b | Query set size restriction
#
# The previous mechanism fails easily, because it is easy to target Alex directly. Another option is to _suppress every query that selects too few users_. So we implemented another privacy mechanism that enforces a query set size restriction (without noise addition). Specifically, if the user count in the response is less than **5**, the query returns __-1__.

# %%
# as before, you can use a direct call to `query_1b("your query")` for exercise 1.b
query_1b = lambda query: remote_query('b'+query, HOST, PORT1)

# %% [markdown]
# **Step 1**: what happens now, when you try your query from exercise 1.a ?

# %%
query_1b( query )
# Out:
# -1

# %% [markdown]
# In this exercise, you will be asked to attack Bob, whose characteristics are as follows:

# %%
# Here are the attributes in Python form ;-)

Bob = { 'age':            50,
        'workclass':       6,
        'education':       9,
        'education_num':  13,
        'marital_status':  2,
        'occupation':      4,
        'relationship':    0,
        'race':            4,
        'sex':             1,
        'capital_gain':    0,
        'capital_loss':    0,
        'hours_per_week': 13,
        'native_country': 39 }

# %% [markdown]
# It doesn't work anymore. However, it does not mean that query set size restriction is the solution for privacy. Indeed, this technique is vulnerable to _intersection attacks_. The idea of an intersection attack is to perform two queries whose answers select several users, but with only one user as the difference between them. Thus, the difference of the two queries gives the exact answer for that user.
#
# Typically, they take the form:
# 1. `Query1 = (condition1 and condition2 and ...)`
# 2. `Query2 = Query1 and Discriminative condition`
#
# Where `Query1` relates to many users, and `Query2` relates to the same users as `Query1` **except for the target user** (for whom the `Discriminative condition` is false). To find these queries, use the target's values, and assert that the count for `Query2` is the same as for `Query1` _minus 1_.
#
# **Step 2  _(action required)_**: Using queries to the server, find (by trial and error) a pair `(Query1, Query2)` using the data _you know_ about Bob.
#
# _Your code should define two variables, called `query1` and `query2`._

# %%
### YOUR CODE HERE
query1 = '' # YOUR QUERY HERE
query2 = '' # YOUR QUERY HERE

### ANSWER
query1 = 'age = 50 and education = 9'
query2 = query1 + ' and hours_per_week <> 13'

# print the content
print(query_1b(query1), query_1b(query2))

# we get: 103 and 102 --> Bob is the only user with (age=50, education=9, hours_per_week=13) and many users
#  have age=50 and education=9

# The idea here is that we used hours_per_week, a high entropy attribute, to discriminate Bob.
# Out:
# 103 102

# %% [markdown]
# **Step 3 _(action required)_**: Using these queries, find Bob's (exact) secret value (you will need to adapt these queries to take into account the `salaryclass`).

# %%
### YOUR CODE HERE

### ANSWER
guess = ' and salaryclass = 1'
difference = query_1b(query1+guess) - query_1b(query2+guess)
print('my guess is: salaryclass = %d' % (difference)) # if query1 = query2, then Bob is not part of query1 or query2 --> Bob's salaryclass is 0
# Out:
# my guess is: salaryclass = 0

# %% [markdown]
# ### Exercise 1c | Noise addition + Query set size restriction
#
# Finally, we could combine these two mechanisms to have a stronger mechanism. Mechanism 1c returns either (-1) if the query concerns less than 5 users, and otherwise the true answer + independent noise according to $\mathcal{N}(0,5)$.

# %%
# you can use a direct call to `query_1c(your_query)` for exercise 1.
query_1c = lambda query: remote_query('c'+query, HOST, PORT1)

# %% [markdown]
# **Step 1**: Use your query from exercise 1a. Is the result informative?

# %%
query_1c(query)
# Out:
# -1

# %% [markdown]
# **Step 2**: Use `query1` and `query2` from exercise 1b. Are the results informative?

# %%
print(query_1c(query1), query_1c(query2))
# Out:
# 100.92534438768934 103.44155683876646

# %% [markdown]
# **Step 3  _(action required)_**: Adapt your attack from exercise 1b to attack this mechanism, and (again) find Bob's secret value. Does combining the mechanisms make them stronger?

# %%
### YOUR CODE HERE

### ANSWER
samples = [query_1b(query1+guess) - query_1b(query2+guess) for _ in range(154)]
print('my guess is: salaryclass = %d' % (np.mean(samples) > 0.5))
# Note: we need twice as many queries because the variance of a difference of gaussians is equal to the sum of variances.
# Out:
# my guess is: salaryclass = 0

# %% [markdown]
# ## Exercise 2
#
# In this second exercise, the query-based system uses _static sticky noise_: it adds noise that depends on the conditions. That is, if a query $Q \equiv$ `C1 and C2 and C3` is issued, our mechanism adds one fixed noise value per condition. The output to Q is then:
# $\newcommand{\static}{\operatorname{static}}$
#
# $$\widetilde{Q}(D) = Q(D) + \static[\text{C1}] + \static[\text{C2}] + \static[\text{C3}],$$
#
# where each $\static[\text{C}x]$ is a noise value drawn from a _seeded_ normal distribution. In this exercise, the mechanism draws from $\mathcal{N}(0,2)$. This means that the noise level for one condition is low, but if you have many conditions in your query, the overall noise will be larger than for the first mechanism. The mechanism is seeded such that if a same condition is used several times (say, in subsequent queries), the same noise will be used every time for that condition.
#
# That is, when you query condition `C1`, a noise `n1` is added to the result (always the same noise), and so on. For instance, you would have the following behaviour, if you do these queries (in whatever order):
# - `C1` ==> answer1 + `n1`
# - `C1 and C2` ==>  answer2 + `n1` + `n2`
# - `C1 and C3` ==> answer3 + `n1` + `n3`
# - `C1` (again) ==> answer1 + `n1`
#
# In practice, this is implemented by [seeding](https://en.wikipedia.org/wiki/Random_seed) the random number generator (RNG) with a hash of the condition (XORed with some salt). The details of the implementation are not important to solve the exercise, but for more details you can look at the slides from last week.
#
# This mechanism thwarts the attack you developed in exercise 1a: repeating the query will always yield the same result.
# To make the mechanism more robust, it also implements query set size restriction, and will return -1 for every query whose user set contains less than 5 users.

# %%
# this is running on a different port of the server!
PORT2 = 42422

# %%
# same as for exercise 1, the function `query_2` is defined for simplicity of use.
query_2 = lambda query: remote_query(query, HOST, PORT2)

# %% [markdown]
# In this exercise, you will attack Carl, whose characteristics are given below.

# %%
Carl = {'age':            43,
        'workclass':       4,
        'education':      15,
        'education_num':  10,
        'marital_status':  2,
        'occupation':     13,
        'relationship':    0,
        'race':            2,
        'sex':             1,
        'capital_gain':    0,
        'capital_loss':    0,
        'hours_per_week': 40,
        'native_country': 23 }

# %% [markdown]
# **Background knowledge**: from your expert knowledge of the situation, you know that Carl is uniquely identified by his `age`, `marital_status`, and `native_country`. Furthermore, you suspect that _many_ people in the dataset share the same `age` and `marital_status` (hence, the `native_country` seems to be a good discriminative condition).
#
# _Why do we have to assume that the adversary knows that?_

# %% [markdown]
# **Step 1**: Perform the following queries. Observe that the result you obtain is the same as your neighbour's. Why is that important?

# %%
### try a few queries here
print('Users aged 42:  \t', query_2('age = 42'))
print('Users aged 1000:\t', query_2('age = 1000'))
print('Number of men:  \t', query_2('sex = 0'))
# Out:
# Users aged 42:  	 781.3844738173221
# Users aged 1000:	 -1
# Number of men:  	 10770.164862533984

# %% [markdown]
# **Step 2  _(action required)_**: Perform your attack 1c here (on Carl). Do you think the result is reliable?

# %%
## YOUR CODE HERE

## ANSWER
c1 = ['age', 'marital_status']
discr = 'native_country'

query1 = ' and '.join( '%s = %s' % (c, Carl[c]) for c in c1)
query2 = query1 + ' and %s <> %s' % (discr, Carl[discr])

samples = [query_2(query1+guess) - query_2(query2+guess) for _ in range(9)]
print(samples)
print('my guess is: salaryclass = %d' % (np.mean(samples) > 0.5)) # ow no it's wrong (in this particular case)
# Out:
# [-0.9182497779437142, -0.9182497779437142, -0.9182497779437142, -0.9182497779437142, -0.9182497779437142, -0.9182497779437142, -0.9182497779437142, -0.9182497779437142, -0.9182497779437142]
# my guess is: salaryclass = 0

# %% [markdown]
# _Spoiler alert_ : this mechanism is still not secure. As you see, this mechanism is still vulnerable to **intersection attacks**. Even if the repeated queries return the same result, the noise on the response is actually _very low_. Why is that?
#
# **Step 3  _(action required)_**: What is the total noise on `query_2(query1) - query_2(query2)` ? Why is it low?

# %% [markdown]
# _Your answer here._
#
# `SAMPLE ANSWER`
#
# Because `query1` and `query2` differ by only one condition, the difference of the results is thus only the noise corresponding to the `Discriminative condition`. This noise is distributed according to $\mathcal{N}(0,2)$.

# %% [markdown]
# While the resulting noise is indeed _small_ , the confidence on your result is low if you can only perform one query. Finding many `(query1, query2)` pairs can be difficult, especially using this more secure interface: it is hard to make sure that Carl is the only user in one query but not the other when the count you find is noisy. In this case, we assume that the pair you already have `(query1, query2)` is _background knowledge_ : something you know about the dataset that you could not figure out by using queries.
#
# However, there is a trick to get more queries, using this single piece of background knowledge: modifying the queries so that they are _semantically equivalent_ but _syntactically different_. For instance, `sex=0` is equivalent to `sex <> 1`. This is called a **semantic attack**.

# %% [markdown]
# **Step 4  _(action required)_**: How many queries do you need for a 95% confidence, given that the noise on one condition is $\mathcal{N}(0,2)$ ?

# %% [markdown]
# _Your answer here._
#
# `SAMPLE ANSWER`
#
# The difference between two queries is distributed according to $\mathcal{N}(0,2)$. The development of exercise 1a still holds. Thus $n \geq 4 \cdot 1.96^2 \cdot 2 = 30.7$. Hence, **31 queries are enough**.

# %% [markdown]
# **Step 5  _(action required)_**: Vary _syntactically_ the `Discriminative condition` (while keeping the same _semantic_ meaning) to obtain independent samples in the difference attack (by obtaining different expressions for `query2`), in order to have enough queries for a confidence of 95%. Perform the attack. Do you obtain the correct result?
#
# _Hint: this SQL database supports arithmetic operations._

# %%
### YOUR CODE HERE

### ANSWER

# we need to find 30 queries ==> 29 equivalents to query2
query2s = [query2]
for x in range(30):
    query2_tmp = query1 + ' and native_country <> (%d + %d)' % (Carl['native_country'] - x, x)
    query2s.append(query2_tmp)

# using these equivalent samples, we can perform the difference attack
samples = [(query_2(query1 + guess) - query_2(q + guess)) for q in query2s]
print(samples)
print('my guess is: salaryclass = %d' % (np.mean(samples) > 0.5)) # yes, it works!
# Out:
# [-0.9182497779437142, -1.1775853129173015, 0.7095874197762555, -0.5668460242313813, 3.2787899648506595, -0.1936358564389309, 1.3724589039698571, 0.926042560092867, 1.4299838025924032, -0.06351527577209026, 0.47380789838010173, -0.09022312850507319, 1.090486626972421, 4.295033910911002, 1.6932596689377988, 1.0551009884456164, -0.5958249367825772, 2.841814828186102, 0.5022953935353769, 2.86763186750008, 3.2170199637105554, 1.9152609460104486, 2.751460954849165, 1.506039091187688, 1.2338554631363934, -0.3992219606829792, 2.6362393886879545, 0.7204307730117421, -0.7546799654964786, 1.3505038337480073, 1.243136992593378]
# my guess is: salaryclass = 1

# %%
query1
# Out:
# 'age = 43 and marital_status = 2'

# %%
query2
# Out:
# 'age = 43 and marital_status = 2 and native_country <> 23'

# %% [markdown]
# ### Bonus exercise: find the age of a record without background knowledge on uniqueness
#
# In this last part, you will attack the same mechanism as for question 2, but _without information on the attributes to use_. That is, in the last part, we told you that the target was unique according to some attributes, but many other users shared all but one of these attributes. Here, you will have to figure out how to get these attributes.
#
# Furthermore, to make it a bit harder, this time we ask you to obtain the `age` (and optionally `salaryclass`) of this record. As always, you are only allowed to query the system through the limited syntax used in this class. Let us know when you have the age (so we can confirm your result)!

# %% [raw]
# age                 ???
# workclass             4
# education            15
# education_num        10
# marital_status        0
# occupation            3
# relationship          4
# race                  4
# sex                   0
# capital_gain          0
# capital_loss          0
# hours_per_week       20
# native_country       39

# %%
Deborah = {'workclass':       4,
           'education':      15,
           'education_num':  10,
           'marital_status':  0,
           'occupation':      3,
           'relationship':    4,
           'race':            4,
           'sex':             0,
           'capital_gain':    0,
           'capital_loss':    0,
           'hours_per_week': 20,
           'native_country': 39 }

# %% [markdown]
# ### A solution
#
# Here is one way you could attack this system. Many more exist, and feel free to play with this and come up with a more efficient solution!
#
# The key issue is that we don't know which subset of attributes can be used to uniquely pinpoint Deborah. The goal is thus to first find a set of attributes $A$ and an attribute $u$ such that $Query(A = a^{Deborah}) = C \gg 5$ and $Query(A = a^{Deborah} \land U \neq u^{Deborah}) = C - 1$.
#
# For this, we can iterate over subsets, and use the trick from the previous exercise to _denoise_ the result sufficiently, so we can make sure that the difference between the two queries is indeed one (and so, $U \neq u^{Deborah}$ is a discriminative condition).
#
# Then, we can simply perform $Query(A = a^{Deborah} \land Age = x)$ and $Query(A = a^{Deborah} \land Age = x \land U \neq u^{Deborah})$ for $x = 1, \dots, 100$, with _denoising_ , until we find a pair for which the difference is exactly 1 (which means that this is Deborah's age). In fact, this doesn't work as is, because $Age = x$ is a very rare condition, so the queries are bucket suppressed. Instead, we use $Age \neq x$ and check for the one query where the difference is 0.

# %% [markdown]
# Step 1: Iterating over subsets $(A',u)$.  **This performs a lot of queries. Can you optimise it?**

# %%
import itertools  # combination of subsets

attributes = list(Deborah.keys())

found = False

# Let's iterate over all subsets of attributes (in fact, we iterate over all pairs X,y).
# We iterate in increasing size (to prevent bucket suppression).
for subset_size in range(2, len(attributes)):
    if found: break
    # Iterate over all subsets of k+1 elements, for k >= 1.
    for subset in itertools.combinations(attributes, subset_size):
        if found: break
        # Iterate over all attributes (setting each as u).
        for i in range(subset_size):
            Aprime = subset[:i] + subset[i+1:]
            u = subset[i]
            # We want to do a difference attack between these queries, to check that
            # the true difference is 1.
            query_1_usr = ' and '.join('%s = %d' % (a, Deborah[a]) for a in Aprime)
            query_2_usr = query_1_usr + ' and %s <> %d' % (u, Deborah[u])
            c1 = query_2(query_1_usr)
            c2 = query_2(query_2_usr)
            diff = c1 - c2
            print('Query: [Aprime = %s, u=%s]: c1=%.3f, c2=%.3f' % (Aprime, u, c1, c2))
            # We want to check if diff ~ N(1, 2). Hence, if diff is too large, then
            #  we can reject. Otherwise, we need more samples.
            if diff > 10:  # Some arbitrary threshold (many standard deviations).
                continue
            # This is a candidate! Let's do many more queries (just to be sure).
            print('Good candidate! Denoising more.')
            q2s = [query_1_usr + ' and %s <> (%d+%d-%d)' % (u, Deborah[u], i, i) for i in range(50)]
            diffs = [diff] + [c1 - query_2(q) for q in q2s]
            diff = np.mean(diffs)
            print('Query: [Aprime = %s, u=%s]: c1=%.3f, diff=%.3f' % (Aprime, u, c1, diff))
            if c1 > 10 and abs( np.mean(diff) - 1 ) < 0.5:  # If the difference is approx ~ 1.
                print('Found!')
                found = True
                break
# Out:
# Query: [Aprime = ('education',), u=workclass]: c1=7290.282, c2=2197.457
# Query: [Aprime = ('workclass',), u=education]: c1=22695.336, c2=17601.748
# Query: [Aprime = ('education_num',), u=workclass]: c1=7291.990, c2=2199.164
# Query: [Aprime = ('workclass',), u=education_num]: c1=22695.336, c2=17601.954
# Query: [Aprime = ('marital_status',), u=workclass]: c1=4442.675, c2=1324.850
# Query: [Aprime = ('workclass',), u=marital_status]: c1=22695.336, c2=19575.418
# Query: [Aprime = ('occupation',), u=workclass]: c1=4100.794, c2=906.969
# Query: [Aprime = ('workclass',), u=occupation]: c1=22695.336, c2=19500.128
# Query: [Aprime = ('relationship',), u=workclass]: c1=3445.622, c2=968.796
# Query: [Aprime = ('workclass',), u=relationship]: c1=22695.336, c2=20217.082
# Query: [Aprime = ('race',), u=workclass]: c1=27814.877, c2=8412.052
# Query: [Aprime = ('workclass',), u=race]: c1=22695.336, c2=3292.352
# Query: [Aprime = ('sex',), u=workclass]: c1=10770.165, c2=3019.339
# Query: [Aprime = ('workclass',), u=sex]: c1=22695.336, c2=14943.575
# Query: [Aprime = ('capital_gain',), u=workclass]: c1=29848.352, c2=8885.526
# Query: [Aprime = ('workclass',), u=capital_gain]: c1=22695.336, c2=1732.601
# Query: [Aprime = ('capital_loss',), u=workclass]: c1=31042.804, c2=9329.978
# Query: [Aprime = ('workclass',), u=capital_loss]: c1=22695.336, c2=979.399
# Query: [Aprime = ('hours_per_week',), u=workclass]: c1=1226.353, c2=411.527
# Query: [Aprime = ('workclass',), u=hours_per_week]: c1=22695.336, c2=21880.586
# Query: [Aprime = ('native_country',), u=workclass]: c1=29168.840, c2=9035.014
# Query: [Aprime = ('workclass',), u=native_country]: c1=22695.336, c2=2562.266
# Query: [Aprime = ('education_num',), u=education]: c1=7291.990, c2=-1.000
# Query: [Aprime = ('education',), u=education_num]: c1=7290.282, c2=-1.000
# Query: [Aprime = ('marital_status',), u=education]: c1=4442.675, c2=3374.087
# Query: [Aprime = ('education',), u=marital_status]: c1=7290.282, c2=6220.364
# Query: [Aprime = ('occupation',), u=education]: c1=4100.794, c2=3233.206
# Query: [Aprime = ('education',), u=occupation]: c1=7290.282, c2=6422.074
# Query: [Aprime = ('relationship',), u=education]: c1=3445.622, c2=2657.034
# Query: [Aprime = ('education',), u=relationship]: c1=7290.282, c2=6501.028
# Query: [Aprime = ('race',), u=education]: c1=27814.877, c2=21608.289
# Query: [Aprime = ('education',), u=race]: c1=7290.282, c2=1084.298
# Query: [Aprime = ('sex',), u=education]: c1=10770.165, c2=7964.577
# Query: [Aprime = ('education',), u=sex]: c1=7290.282, c2=4484.521
# Query: [Aprime = ('capital_gain',), u=education]: c1=29848.352, c2=23030.764
# Query: [Aprime = ('education',), u=capital_gain]: c1=7290.282, c2=473.548
# Query: [Aprime = ('capital_loss',), u=education]: c1=31042.804, c2=24037.216
# Query: [Aprime = ('education',), u=capital_loss]: c1=7290.282, c2=282.346
# Query: [Aprime = ('hours_per_week',), u=education]: c1=1226.353, c2=827.765
# Query: [Aprime = ('education',), u=hours_per_week]: c1=7290.282, c2=6892.532
# Query: [Aprime = ('native_country',), u=education]: c1=29168.840, c2=22429.252
# Query: [Aprime = ('education',), u=native_country]: c1=7290.282, c2=552.212
# Query: [Aprime = ('marital_status',), u=education_num]: c1=4442.675, c2=3374.293
# Query: [Aprime = ('education_num',), u=marital_status]: c1=7291.990, c2=6222.071
# Query: [Aprime = ('occupation',), u=education_num]: c1=4100.794, c2=3233.412
# Query: [Aprime = ('education_num',), u=occupation]: c1=7291.990, c2=6423.782
# Query: [Aprime = ('relationship',), u=education_num]: c1=3445.622, c2=2657.239
# Query: [Aprime = ('education_num',), u=relationship]: c1=7291.990, c2=6502.736
# Query: [Aprime = ('race',), u=education_num]: c1=27814.877, c2=21608.495
# Query: [Aprime = ('education_num',), u=race]: c1=7291.990, c2=1086.006
# Query: [Aprime = ('sex',), u=education_num]: c1=10770.165, c2=7964.782
# Query: [Aprime = ('education_num',), u=sex]: c1=7291.990, c2=4486.229
# Query: [Aprime = ('capital_gain',), u=education_num]: c1=29848.352, c2=23030.969
# Query: [Aprime = ('education_num',), u=capital_gain]: c1=7291.990, c2=475.255
# Query: [Aprime = ('capital_loss',), u=education_num]: c1=31042.804, c2=24037.421
# Query: [Aprime = ('education_num',), u=capital_loss]: c1=7291.990, c2=284.053
# Query: [Aprime = ('hours_per_week',), u=education_num]: c1=1226.353, c2=827.970
# Query: [Aprime = ('education_num',), u=hours_per_week]: c1=7291.990, c2=6894.239
# Query: [Aprime = ('native_country',), u=education_num]: c1=29168.840, c2=22429.457
# Query: [Aprime = ('education_num',), u=native_country]: c1=7291.990, c2=553.920
# Query: [Aprime = ('occupation',), u=marital_status]: c1=4100.794, c2=3635.876
# Query: [Aprime = ('marital_status',), u=occupation]: c1=4442.675, c2=3978.468
# Query: [Aprime = ('relationship',), u=marital_status]: c1=3445.622, c2=1843.703
# Query: [Aprime = ('marital_status',), u=relationship]: c1=4442.675, c2=2841.421
# Query: [Aprime = ('race',), u=marital_status]: c1=27814.877, c2=24016.959
# Query: [Aprime = ('marital_status',), u=race]: c1=4442.675, c2=646.692
# Query: [Aprime = ('sex',), u=marital_status]: c1=10770.165, c2=8097.247
# Query: [Aprime = ('marital_status',), u=sex]: c1=4442.675, c2=1770.914
# Query: [Aprime = ('capital_gain',), u=marital_status]: c1=29848.352, c2=25692.434
# Query: [Aprime = ('marital_status',), u=capital_gain]: c1=4442.675, c2=288.941
# Query: [Aprime = ('capital_loss',), u=marital_status]: c1=31042.804, c2=26763.886
# Query: [Aprime = ('marital_status',), u=capital_loss]: c1=4442.675, c2=162.739
# Query: [Aprime = ('hours_per_week',), u=marital_status]: c1=1226.353, c2=1127.435
# Query: [Aprime = ('marital_status',), u=hours_per_week]: c1=4442.675, c2=4345.925
# Query: [Aprime = ('native_country',), u=marital_status]: c1=29168.840, c2=25005.922
# Query: [Aprime = ('marital_status',), u=native_country]: c1=4442.675, c2=282.606
# Query: [Aprime = ('relationship',), u=occupation]: c1=3445.622, c2=3198.414
# Query: [Aprime = ('occupation',), u=relationship]: c1=4100.794, c2=3853.540
# Query: [Aprime = ('race',), u=occupation]: c1=27814.877, c2=24120.669
# Query: [Aprime = ('occupation',), u=race]: c1=4100.794, c2=407.811
# Query: [Aprime = ('sex',), u=occupation]: c1=10770.165, c2=10547.957
# Query: [Aprime = ('occupation',), u=sex]: c1=4100.794, c2=3879.033
# Query: [Aprime = ('capital_gain',), u=occupation]: c1=29848.352, c2=26058.144
# Query: [Aprime = ('occupation',), u=capital_gain]: c1=4100.794, c2=312.060
# Query: [Aprime = ('capital_loss',), u=occupation]: c1=31042.804, c2=27140.596
# Query: [Aprime = ('occupation',), u=capital_loss]: c1=4100.794, c2=196.858
# Query: [Aprime = ('hours_per_week',), u=occupation]: c1=1226.353, c2=1176.145
# Query: [Aprime = ('occupation',), u=hours_per_week]: c1=4100.794, c2=4052.044
# Query: [Aprime = ('native_country',), u=occupation]: c1=29168.840, c2=25483.632
# Query: [Aprime = ('occupation',), u=native_country]: c1=4100.794, c2=417.725
# Query: [Aprime = ('race',), u=relationship]: c1=27814.877, c2=25323.623
# Query: [Aprime = ('relationship',), u=race]: c1=3445.622, c2=955.638
# Query: [Aprime = ('sex',), u=relationship]: c1=10770.165, c2=8115.911
# Query: [Aprime = ('relationship',), u=sex]: c1=3445.622, c2=791.861
# Query: [Aprime = ('capital_gain',), u=relationship]: c1=29848.352, c2=26586.098
# Query: [Aprime = ('relationship',), u=capital_gain]: c1=3445.622, c2=184.887
# Query: [Aprime = ('capital_loss',), u=relationship]: c1=31042.804, c2=27686.550
# Query: [Aprime = ('relationship',), u=capital_loss]: c1=3445.622, c2=87.685
# Query: [Aprime = ('hours_per_week',), u=relationship]: c1=1226.353, c2=1110.099
# Query: [Aprime = ('relationship',), u=hours_per_week]: c1=3445.622, c2=3330.871
# Query: [Aprime = ('native_country',), u=relationship]: c1=29168.840, c2=26135.586
# Query: [Aprime = ('relationship',), u=native_country]: c1=3445.622, c2=414.552
# Query: [Aprime = ('sex',), u=race]: c1=10770.165, c2=2129.181
# Query: [Aprime = ('race',), u=sex]: c1=27814.877, c2=19173.116
# Query: [Aprime = ('capital_gain',), u=race]: c1=29848.352, c2=4442.368
# Query: [Aprime = ('race',), u=capital_gain]: c1=27814.877, c2=2409.143
# Query: [Aprime = ('capital_loss',), u=race]: c1=31042.804, c2=4573.820
# Query: [Aprime = ('race',), u=capital_loss]: c1=27814.877, c2=1342.941
# Query: [Aprime = ('hours_per_week',), u=race]: c1=1226.353, c2=216.369
# Query: [Aprime = ('race',), u=hours_per_week]: c1=27814.877, c2=26805.127
# Query: [Aprime = ('native_country',), u=race]: c1=29168.840, c2=3548.856
# Query: [Aprime = ('race',), u=native_country]: c1=27814.877, c2=2195.807
# Query: [Aprime = ('capital_gain',), u=sex]: c1=29848.352, c2=19700.591
# Query: [Aprime = ('sex',), u=capital_gain]: c1=10770.165, c2=623.430
# Query: [Aprime = ('capital_loss',), u=sex]: c1=31042.804, c2=20641.043
# Query: [Aprime = ('sex',), u=capital_loss]: c1=10770.165, c2=366.228
# Query: [Aprime = ('hours_per_week',), u=sex]: c1=1226.353, c2=582.592
# Query: [Aprime = ('sex',), u=hours_per_week]: c1=10770.165, c2=10127.414
# Query: [Aprime = ('native_country',), u=sex]: c1=29168.840, c2=19487.079
# Query: [Aprime = ('sex',), u=native_country]: c1=10770.165, c2=1090.095
# Query: [Aprime = ('capital_loss',), u=capital_gain]: c1=31042.804, c2=2714.069
# Query: [Aprime = ('capital_gain',), u=capital_loss]: c1=29848.352, c2=1516.415
# Query: [Aprime = ('hours_per_week',), u=capital_gain]: c1=1226.353, c2=65.618
# Query: [Aprime = ('capital_gain',), u=hours_per_week]: c1=29848.352, c2=28687.601
# Query: [Aprime = ('native_country',), u=capital_gain]: c1=29168.840, c2=2471.105
# Query: [Aprime = ('capital_gain',), u=native_country]: c1=29848.352, c2=3151.282
# Query: [Aprime = ('hours_per_week',), u=capital_loss]: c1=1226.353, c2=35.416
# Query: [Aprime = ('capital_loss',), u=hours_per_week]: c1=31042.804, c2=29855.053
# Query: [Aprime = ('native_country',), u=capital_loss]: c1=29168.840, c2=1375.903
# Query: [Aprime = ('capital_loss',), u=native_country]: c1=31042.804, c2=3253.734
# Query: [Aprime = ('native_country',), u=hours_per_week]: c1=29168.840, c2=28046.089
# Query: [Aprime = ('hours_per_week',), u=native_country]: c1=1226.353, c2=104.283
# Query: [Aprime = ('education', 'education_num'), u=workclass]: c1=7291.272, c2=2198.446
# Query: [Aprime = ('workclass', 'education_num'), u=education]: c1=5094.326, c2=-1.000
# Query: [Aprime = ('workclass', 'education'), u=education_num]: c1=5092.618, c2=-1.000
# Query: [Aprime = ('education', 'marital_status'), u=workclass]: c1=1067.958, c2=314.132
# Query: [Aprime = ('workclass', 'marital_status'), u=education]: c1=3118.012, c2=2363.423
# Query: [Aprime = ('workclass', 'education'), u=marital_status]: c1=5092.618, c2=4336.700
# Query: [Aprime = ('education', 'occupation'), u=workclass]: c1=869.077, c2=202.251
# Query: [Aprime = ('workclass', 'occupation'), u=education]: c1=3196.131, c2=2528.542
# Query: [Aprime = ('workclass', 'education'), u=occupation]: c1=5092.618, c2=4424.411
# Query: [Aprime = ('education', 'relationship'), u=workclass]: c1=787.904, c2=241.078
# Query: [Aprime = ('workclass', 'relationship'), u=education]: c1=2476.958, c2=1929.370
# Query: [Aprime = ('workclass', 'education'), u=relationship]: c1=5092.618, c2=4544.364
# Query: [Aprime = ('education', 'race'), u=workclass]: c1=6205.160, c2=1849.334
# Query: [Aprime = ('workclass', 'race'), u=education]: c1=19402.213, c2=15045.625
# Query: [Aprime = ('workclass', 'education'), u=race]: c1=5092.618, c2=736.635
# Query: [Aprime = ('education', 'sex'), u=workclass]: c1=2804.447, c2=785.622
# Query: [Aprime = ('workclass', 'sex'), u=education]: c1=7750.501, c2=5730.913
# Query: [Aprime = ('workclass', 'education'), u=sex]: c1=5092.618, c2=3072.857
# Query: [Aprime = ('education', 'capital_gain'), u=workclass]: c1=6816.634, c2=2041.809
# Query: [Aprime = ('workclass', 'capital_gain'), u=education]: c1=20962.688, c2=16187.100
# Query: [Aprime = ('workclass', 'education'), u=capital_gain]: c1=5092.618, c2=317.884
# Query: [Aprime = ('education', 'capital_loss'), u=workclass]: c1=7006.086, c2=2104.260
# Query: [Aprime = ('workclass', 'capital_loss'), u=education]: c1=21714.140, c2=16811.552
# Query: [Aprime = ('workclass', 'education'), u=capital_loss]: c1=5092.618, c2=187.682
# Query: [Aprime = ('education', 'hours_per_week'), u=workclass]: c1=400.635, c2=121.810
# Query: [Aprime = ('workclass', 'hours_per_week'), u=education]: c1=817.689, c2=538.101
# Query: [Aprime = ('workclass', 'education'), u=hours_per_week]: c1=5092.618, c2=4813.868
# Query: [Aprime = ('education', 'native_country'), u=workclass]: c1=6738.122, c2=2061.297
# Query: [Aprime = ('workclass', 'native_country'), u=education]: c1=20133.176, c2=15455.588
# Query: [Aprime = ('workclass', 'education'), u=native_country]: c1=5092.618, c2=416.549
# Query: [Aprime = ('education_num', 'marital_status'), u=workclass]: c1=1069.665, c2=315.839
# Query: [Aprime = ('workclass', 'marital_status'), u=education_num]: c1=3118.012, c2=2363.629
# Query: [Aprime = ('workclass', 'education_num'), u=marital_status]: c1=5094.326, c2=4338.408
# Query: [Aprime = ('education_num', 'occupation'), u=workclass]: c1=870.784, c2=203.958
# Query: [Aprime = ('workclass', 'occupation'), u=education_num]: c1=3196.131, c2=2528.748
# Query: [Aprime = ('workclass', 'education_num'), u=occupation]: c1=5094.326, c2=4426.118
# Query: [Aprime = ('education_num', 'relationship'), u=workclass]: c1=789.611, c2=242.786
# Query: [Aprime = ('workclass', 'relationship'), u=education_num]: c1=2476.958, c2=1929.575
# Query: [Aprime = ('workclass', 'education_num'), u=relationship]: c1=5094.326, c2=4546.072
# Query: [Aprime = ('education_num', 'race'), u=workclass]: c1=6206.867, c2=1851.041
# Query: [Aprime = ('workclass', 'race'), u=education_num]: c1=19402.213, c2=15045.831
# Query: [Aprime = ('workclass', 'education_num'), u=race]: c1=5094.326, c2=738.342
# Query: [Aprime = ('education_num', 'sex'), u=workclass]: c1=2806.155, c2=787.329
# Query: [Aprime = ('workclass', 'sex'), u=education_num]: c1=7750.501, c2=5731.118
# Query: [Aprime = ('workclass', 'education_num'), u=sex]: c1=5094.326, c2=3074.565
# Query: [Aprime = ('education_num', 'capital_gain'), u=workclass]: c1=6818.342, c2=2043.516
# Query: [Aprime = ('workclass', 'capital_gain'), u=education_num]: c1=20962.688, c2=16187.306
# Query: [Aprime = ('workclass', 'education_num'), u=capital_gain]: c1=5094.326, c2=319.591
# Query: [Aprime = ('education_num', 'capital_loss'), u=workclass]: c1=7007.793, c2=2105.968
# Query: [Aprime = ('workclass', 'capital_loss'), u=education_num]: c1=21714.140, c2=16811.757
# Query: [Aprime = ('workclass', 'education_num'), u=capital_loss]: c1=5094.326, c2=189.389
# Query: [Aprime = ('education_num', 'hours_per_week'), u=workclass]: c1=402.343, c2=123.517
# Query: [Aprime = ('workclass', 'hours_per_week'), u=education_num]: c1=817.689, c2=538.306
# Query: [Aprime = ('workclass', 'education_num'), u=hours_per_week]: c1=5094.326, c2=4815.575
# Query: [Aprime = ('education_num', 'native_country'), u=workclass]: c1=6739.830, c2=2063.004
# Query: [Aprime = ('workclass', 'native_country'), u=education_num]: c1=20133.176, c2=15455.793
# Query: [Aprime = ('workclass', 'education_num'), u=native_country]: c1=5094.326, c2=418.256
# Query: [Aprime = ('marital_status', 'occupation'), u=workclass]: c1=465.470, c2=98.644
# Query: [Aprime = ('workclass', 'occupation'), u=marital_status]: c1=3196.131, c2=2827.212
# Query: [Aprime = ('workclass', 'marital_status'), u=occupation]: c1=3118.012, c2=2749.804
# Query: [Aprime = ('marital_status', 'relationship'), u=workclass]: c1=1600.297, c2=484.471
# Query: [Aprime = ('workclass', 'relationship'), u=marital_status]: c1=2476.958, c2=1359.040
# Query: [Aprime = ('workclass', 'marital_status'), u=relationship]: c1=3118.012, c2=2000.757
# Query: [Aprime = ('marital_status', 'race'), u=workclass]: c1=3795.553, c2=1092.727
# Query: [Aprime = ('workclass', 'race'), u=marital_status]: c1=19402.213, c2=16697.295
# Query: [Aprime = ('workclass', 'marital_status'), u=race]: c1=3118.012, c2=415.028
# Query: [Aprime = ('marital_status', 'sex'), u=workclass]: c1=2670.840, c2=768.015
# Query: [Aprime = ('workclass', 'sex'), u=marital_status]: c1=7750.501, c2=5845.583
# Query: [Aprime = ('workclass', 'marital_status'), u=sex]: c1=3118.012, c2=1214.251
# Query: [Aprime = ('marital_status', 'capital_gain'), u=workclass]: c1=4154.027, c2=1217.202
# Query: [Aprime = ('workclass', 'capital_gain'), u=marital_status]: c1=20962.688, c2=18023.770
# Query: [Aprime = ('workclass', 'marital_status'), u=capital_gain]: c1=3118.012, c2=181.277
# Query: [Aprime = ('marital_status', 'capital_loss'), u=workclass]: c1=4278.479, c2=1279.654
# Query: [Aprime = ('workclass', 'capital_loss'), u=marital_status]: c1=21714.140, c2=18713.222
# Query: [Aprime = ('workclass', 'marital_status'), u=capital_loss]: c1=3118.012, c2=116.075
# Query: [Aprime = ('marital_status', 'hours_per_week'), u=workclass]: c1=100.028, c2=42.203
# Query: [Aprime = ('workclass', 'hours_per_week'), u=marital_status]: c1=817.689, c2=757.771
# Query: [Aprime = ('workclass', 'marital_status'), u=hours_per_week]: c1=3118.012, c2=3060.261
# Query: [Aprime = ('marital_status', 'native_country'), u=workclass]: c1=4160.515, c2=1232.690
# Query: [Aprime = ('workclass', 'native_country'), u=marital_status]: c1=20133.176, c2=17203.258
# Query: [Aprime = ('workclass', 'marital_status'), u=native_country]: c1=3118.012, c2=190.942
# Query: [Aprime = ('occupation', 'relationship'), u=workclass]: c1=248.416, c2=39.590
# Query: [Aprime = ('workclass', 'relationship'), u=occupation]: c1=2476.958, c2=2266.750
# Query: [Aprime = ('workclass', 'occupation'), u=relationship]: c1=3196.131, c2=2985.876
# Query: [Aprime = ('occupation', 'race'), u=workclass]: c1=3694.672, c2=832.846
# Query: [Aprime = ('workclass', 'race'), u=occupation]: c1=19402.213, c2=16539.006
# Query: [Aprime = ('workclass', 'occupation'), u=race]: c1=3196.131, c2=334.147
# Query: [Aprime = ('occupation', 'sex'), u=workclass]: c1=222.959, c2=30.134
# Query: [Aprime = ('workclass', 'sex'), u=occupation]: c1=7750.501, c2=7556.293
# Query: [Aprime = ('workclass', 'occupation'), u=sex]: c1=3196.131, c2=3002.370
# Query: [Aprime = ('occupation', 'capital_gain'), u=workclass]: c1=3791.146, c2=834.321
# Query: [Aprime = ('workclass', 'capital_gain'), u=occupation]: c1=20962.688, c2=18004.480
# Query: [Aprime = ('workclass', 'occupation'), u=capital_gain]: c1=3196.131, c2=239.396
# Query: [Aprime = ('occupation', 'capital_loss'), u=workclass]: c1=3904.598, c2=857.772
# Query: [Aprime = ('workclass', 'capital_loss'), u=occupation]: c1=21714.140, c2=18665.932
# Query: [Aprime = ('workclass', 'occupation'), u=capital_loss]: c1=3196.131, c2=146.194
# Query: [Aprime = ('occupation', 'hours_per_week'), u=workclass]: c1=54.147, c2=26.322
# Query: [Aprime = ('workclass', 'hours_per_week'), u=occupation]: c1=817.689, c2=788.481
# Query: [Aprime = ('workclass', 'occupation'), u=hours_per_week]: c1=3196.131, c2=3168.380
# Query: [Aprime = ('occupation', 'native_country'), u=workclass]: c1=3685.634, c2=832.809
# Query: [Aprime = ('workclass', 'native_country'), u=occupation]: c1=20133.176, c2=17278.968
# Query: [Aprime = ('workclass', 'occupation'), u=native_country]: c1=3196.131, c2=344.061
# Query: [Aprime = ('relationship', 'race'), u=workclass]: c1=2489.499, c2=669.673
# Query: [Aprime = ('workclass', 'race'), u=relationship]: c1=19402.213, c2=17580.959
# Query: [Aprime = ('workclass', 'relationship'), u=race]: c1=2476.958, c2=656.974
# Query: [Aprime = ('relationship', 'sex'), u=workclass]: c1=2652.787, c2=743.961
# Query: [Aprime = ('workclass', 'sex'), u=relationship]: c1=7750.501, c2=5840.247
# Query: [Aprime = ('workclass', 'relationship'), u=sex]: c1=2476.958, c2=567.197
# Query: [Aprime = ('relationship', 'capital_gain'), u=workclass]: c1=3260.974, c2=896.148
# Query: [Aprime = ('workclass', 'capital_gain'), u=relationship]: c1=20962.688, c2=18596.434
# Query: [Aprime = ('workclass', 'relationship'), u=capital_gain]: c1=2476.958, c2=112.223
# Query: [Aprime = ('relationship', 'capital_loss'), u=workclass]: c1=3356.425, c2=944.600
# Query: [Aprime = ('workclass', 'capital_loss'), u=relationship]: c1=21714.140, c2=19300.886
# Query: [Aprime = ('workclass', 'relationship'), u=capital_loss]: c1=2476.958, c2=62.021
# Query: [Aprime = ('relationship', 'hours_per_week'), u=workclass]: c1=117.975, c2=44.149
# Query: [Aprime = ('workclass', 'hours_per_week'), u=relationship]: c1=817.689, c2=742.435
# Query: [Aprime = ('workclass', 'relationship'), u=hours_per_week]: c1=2476.958, c2=2403.207
# Query: [Aprime = ('relationship', 'native_country'), u=workclass]: c1=3031.462, c2=881.636
# Query: [Aprime = ('workclass', 'native_country'), u=relationship]: c1=20133.176, c2=17981.922
# Query: [Aprime = ('workclass', 'relationship'), u=native_country]: c1=2476.958, c2=327.888
# Query: [Aprime = ('race', 'sex'), u=workclass]: c1=8640.042, c2=2360.216
# Query: [Aprime = ('workclass', 'sex'), u=race]: c1=7750.501, c2=1470.517
# Query: [Aprime = ('workclass', 'race'), u=sex]: c1=19402.213, c2=13121.452
# Query: [Aprime = ('race', 'capital_gain'), u=workclass]: c1=25405.229, c2=7542.404
# Query: [Aprime = ('workclass', 'capital_gain'), u=race]: c1=20962.688, c2=3099.704
# Query: [Aprime = ('workclass', 'race'), u=capital_gain]: c1=19402.213, c2=1539.479
# Query: [Aprime = ('race', 'capital_loss'), u=workclass]: c1=26469.681, c2=7942.855
# Query: [Aprime = ('workclass', 'capital_loss'), u=race]: c1=21714.140, c2=3187.156
# Query: [Aprime = ('workclass', 'race'), u=capital_loss]: c1=19402.213, c2=872.277
# Query: [Aprime = ('race', 'hours_per_week'), u=workclass]: c1=1012.230, c2=337.405
# Query: [Aprime = ('workclass', 'hours_per_week'), u=race]: c1=817.689, c2=142.705
# Query: [Aprime = ('workclass', 'race'), u=hours_per_week]: c1=19402.213, c2=18727.463
# Query: [Aprime = ('race', 'native_country'), u=workclass]: c1=25618.717, c2=7891.892
# Query: [Aprime = ('workclass', 'native_country'), u=race]: c1=20133.176, c2=2406.192
# Query: [Aprime = ('workclass', 'race'), u=native_country]: c1=19402.213, c2=1676.144
# Query: [Aprime = ('sex', 'capital_gain'), u=workclass]: c1=10146.517, c2=2787.691
# Query: [Aprime = ('workclass', 'capital_gain'), u=sex]: c1=20962.688, c2=13602.927
# Query: [Aprime = ('workclass', 'sex'), u=capital_gain]: c1=7750.501, c2=391.766
# Query: [Aprime = ('sex', 'capital_loss'), u=workclass]: c1=10401.969, c2=2898.143
# Query: [Aprime = ('workclass', 'capital_loss'), u=sex]: c1=21714.140, c2=14209.379
# Query: [Aprime = ('workclass', 'sex'), u=capital_loss]: c1=7750.501, c2=243.564
# Query: [Aprime = ('sex', 'hours_per_week'), u=workclass]: c1=645.518, c2=203.692
# Query: [Aprime = ('workclass', 'hours_per_week'), u=sex]: c1=817.689, c2=374.928
# Query: [Aprime = ('workclass', 'sex'), u=hours_per_week]: c1=7750.501, c2=7308.750
# Query: [Aprime = ('sex', 'native_country'), u=workclass]: c1=9680.005, c2=2755.179
# Query: [Aprime = ('workclass', 'native_country'), u=sex]: c1=20133.176, c2=13207.415
# Query: [Aprime = ('workclass', 'sex'), u=native_country]: c1=7750.501, c2=826.431
# Query: [Aprime = ('capital_gain', 'capital_loss'), u=workclass]: c1=28330.156, c2=8349.330
# Query: [Aprime = ('workclass', 'capital_loss'), u=capital_gain]: c1=21714.140, c2=1733.405
# Query: [Aprime = ('workclass', 'capital_gain'), u=capital_loss]: c1=20962.688, c2=978.751
# Query: [Aprime = ('capital_gain', 'hours_per_week'), u=workclass]: c1=1163.705, c2=385.879
# Query: [Aprime = ('workclass', 'hours_per_week'), u=capital_gain]: c1=817.689, c2=39.954
# Query: [Aprime = ('workclass', 'capital_gain'), u=hours_per_week]: c1=20962.688, c2=20184.937
# Query: [Aprime = ('capital_gain', 'native_country'), u=workclass]: c1=26697.192, c2=8140.366
# Query: [Aprime = ('workclass', 'native_country'), u=capital_gain]: c1=20133.176, c2=1576.441
# Query: [Aprime = ('workclass', 'capital_gain'), u=native_country]: c1=20962.688, c2=2406.618
# Query: [Aprime = ('capital_loss', 'hours_per_week'), u=workclass]: c1=1192.157, c2=396.331
# Query: [Aprime = ('workclass', 'hours_per_week'), u=capital_loss]: c1=817.689, c2=18.752
# Query: [Aprime = ('workclass', 'capital_loss'), u=hours_per_week]: c1=21714.140, c2=20918.389
# Query: [Aprime = ('capital_loss', 'native_country'), u=workclass]: c1=27790.644, c2=8554.818
# Query: [Aprime = ('workclass', 'native_country'), u=capital_loss]: c1=20133.176, c2=894.239
# Query: [Aprime = ('workclass', 'capital_loss'), u=native_country]: c1=21714.140, c2=2479.070
# Query: [Aprime = ('hours_per_week', 'native_country'), u=workclass]: c1=1125.193, c2=372.367
# Query: [Aprime = ('workclass', 'native_country'), u=hours_per_week]: c1=20133.176, c2=19380.425
# Query: [Aprime = ('workclass', 'hours_per_week'), u=native_country]: c1=817.689, c2=65.619
# Query: [Aprime = ('education_num', 'marital_status'), u=education]: c1=1069.665, c2=-1.000
# Query: [Aprime = ('education', 'marital_status'), u=education_num]: c1=1067.958, c2=-1.000
# Query: [Aprime = ('education', 'education_num'), u=marital_status]: c1=7291.272, c2=6221.354
# Query: [Aprime = ('education_num', 'occupation'), u=education]: c1=870.784, c2=-1.000
# Query: [Aprime = ('education', 'occupation'), u=education_num]: c1=869.077, c2=-1.000
# Query: [Aprime = ('education', 'education_num'), u=occupation]: c1=7291.272, c2=6423.064
# Query: [Aprime = ('education_num', 'relationship'), u=education]: c1=789.611, c2=-1.000
# Query: [Aprime = ('education', 'relationship'), u=education_num]: c1=787.904, c2=-1.000
# Query: [Aprime = ('education', 'education_num'), u=relationship]: c1=7291.272, c2=6502.018
# Query: [Aprime = ('education_num', 'race'), u=education]: c1=6206.867, c2=-1.000
# Query: [Aprime = ('education', 'race'), u=education_num]: c1=6205.160, c2=-1.000
# Query: [Aprime = ('education', 'education_num'), u=race]: c1=7291.272, c2=1085.288
# Query: [Aprime = ('education_num', 'sex'), u=education]: c1=2806.155, c2=-1.000
# Query: [Aprime = ('education', 'sex'), u=education_num]: c1=2804.447, c2=-1.000
# Query: [Aprime = ('education', 'education_num'), u=sex]: c1=7291.272, c2=4485.511
# Query: [Aprime = ('education_num', 'capital_gain'), u=education]: c1=6818.342, c2=-1.000
# Query: [Aprime = ('education', 'capital_gain'), u=education_num]: c1=6816.634, c2=-1.000
# Query: [Aprime = ('education', 'education_num'), u=capital_gain]: c1=7291.272, c2=474.537
# Query: [Aprime = ('education_num', 'capital_loss'), u=education]: c1=7007.793, c2=-1.000
# Query: [Aprime = ('education', 'capital_loss'), u=education_num]: c1=7006.086, c2=-1.000
# Query: [Aprime = ('education', 'education_num'), u=capital_loss]: c1=7291.272, c2=283.335
# Query: [Aprime = ('education_num', 'hours_per_week'), u=education]: c1=402.343, c2=-1.000
# Query: [Aprime = ('education', 'hours_per_week'), u=education_num]: c1=400.635, c2=-1.000
# Query: [Aprime = ('education', 'education_num'), u=hours_per_week]: c1=7291.272, c2=6893.521
# Query: [Aprime = ('education_num', 'native_country'), u=education]: c1=6739.830, c2=-1.000
# Query: [Aprime = ('education', 'native_country'), u=education_num]: c1=6738.122, c2=-1.000
# Query: [Aprime = ('education', 'education_num'), u=native_country]: c1=7291.272, c2=553.202
# Query: [Aprime = ('marital_status', 'occupation'), u=education]: c1=465.470, c2=369.882
# Query: [Aprime = ('education', 'occupation'), u=marital_status]: c1=869.077, c2=772.159
# Query: [Aprime = ('education', 'marital_status'), u=occupation]: c1=1067.958, c2=971.750
# Query: [Aprime = ('marital_status', 'relationship'), u=education]: c1=1600.297, c2=1178.709
# Query: [Aprime = ('education', 'relationship'), u=marital_status]: c1=787.904, c2=364.986
# Query: [Aprime = ('education', 'marital_status'), u=relationship]: c1=1067.958, c2=645.704
# Query: [Aprime = ('marital_status', 'race'), u=education]: c1=3795.553, c2=2886.965
# Query: [Aprime = ('education', 'race'), u=marital_status]: c1=6205.160, c2=5295.241
# Query: [Aprime = ('education', 'marital_status'), u=race]: c1=1067.958, c2=159.974
# Query: [Aprime = ('marital_status', 'sex'), u=education]: c1=2670.840, c2=1960.252
# Query: [Aprime = ('education', 'sex'), u=marital_status]: c1=2804.447, c2=2092.529
# Query: [Aprime = ('education', 'marital_status'), u=sex]: c1=1067.958, c2=357.197
# Query: [Aprime = ('marital_status', 'capital_gain'), u=education]: c1=4154.027, c2=3135.439
# Query: [Aprime = ('education', 'capital_gain'), u=marital_status]: c1=6816.634, c2=5796.716
# Query: [Aprime = ('education', 'marital_status'), u=capital_gain]: c1=1067.958, c2=50.223
# Query: [Aprime = ('marital_status', 'capital_loss'), u=education]: c1=4278.479, c2=3237.891
# Query: [Aprime = ('education', 'capital_loss'), u=marital_status]: c1=7006.086, c2=5964.168
# Query: [Aprime = ('education', 'marital_status'), u=capital_loss]: c1=1067.958, c2=25.021
# Query: [Aprime = ('marital_status', 'hours_per_week'), u=education]: c1=100.028, c2=69.440
# Query: [Aprime = ('education', 'hours_per_week'), u=marital_status]: c1=400.635, c2=368.717
# Query: [Aprime = ('education', 'marital_status'), u=hours_per_week]: c1=1067.958, c2=1038.207
# Query: [Aprime = ('marital_status', 'native_country'), u=education]: c1=4160.515, c2=3150.927
# Query: [Aprime = ('education', 'native_country'), u=marital_status]: c1=6738.122, c2=5727.204
# Query: [Aprime = ('education', 'marital_status'), u=native_country]: c1=1067.958, c2=59.888
# Query: [Aprime = ('occupation', 'relationship'), u=education]: c1=248.416, c2=196.828
# Query: [Aprime = ('education', 'relationship'), u=occupation]: c1=787.904, c2=735.696
# Query: [Aprime = ('education', 'occupation'), u=relationship]: c1=869.077, c2=816.823
# Query: [Aprime = ('occupation', 'race'), u=education]: c1=3694.672, c2=2916.084
# Query: [Aprime = ('education', 'race'), u=occupation]: c1=6205.160, c2=5425.952
# Query: [Aprime = ('education', 'occupation'), u=race]: c1=869.077, c2=91.093
# Query: [Aprime = ('occupation', 'sex'), u=education]: c1=222.959, c2=174.371
# Query: [Aprime = ('education', 'sex'), u=occupation]: c1=2804.447, c2=2755.239
# Query: [Aprime = ('education', 'occupation'), u=sex]: c1=869.077, c2=820.316
# Query: [Aprime = ('occupation', 'capital_gain'), u=education]: c1=3791.146, c2=2994.558
# Query: [Aprime = ('education', 'capital_gain'), u=occupation]: c1=6816.634, c2=6019.426
# Query: [Aprime = ('education', 'occupation'), u=capital_gain]: c1=869.077, c2=73.342
# Query: [Aprime = ('occupation', 'capital_loss'), u=education]: c1=3904.598, c2=3081.010
# Query: [Aprime = ('education', 'capital_loss'), u=occupation]: c1=7006.086, c2=6181.878
# Query: [Aprime = ('education', 'occupation'), u=capital_loss]: c1=869.077, c2=43.140
# Query: [Aprime = ('occupation', 'hours_per_week'), u=education]: c1=54.147, c2=45.559
# Good candidate! Denoising more.
# Query: [Aprime = ('occupation', 'hours_per_week'), u=education]: c1=54.147, diff=9.043
# Query: [Aprime = ('education', 'hours_per_week'), u=occupation]: c1=400.635, c2=391.427
# Good candidate! Denoising more.
# Query: [Aprime = ('education', 'hours_per_week'), u=occupation]: c1=400.635, diff=9.084
# Query: [Aprime = ('education', 'occupation'), u=hours_per_week]: c1=869.077, c2=861.326
# Good candidate! Denoising more.
# Query: [Aprime = ('education', 'occupation'), u=hours_per_week]: c1=869.077, diff=9.295
# Query: [Aprime = ('occupation', 'native_country'), u=education]: c1=3685.634, c2=2894.046
# Query: [Aprime = ('education', 'native_country'), u=occupation]: c1=6738.122, c2=5945.914
# Query: [Aprime = ('education', 'occupation'), u=native_country]: c1=869.077, c2=79.007
# Query: [Aprime = ('relationship', 'race'), u=education]: c1=2489.499, c2=1927.911
# Query: [Aprime = ('education', 'race'), u=relationship]: c1=6205.160, c2=5642.905
# Query: [Aprime = ('education', 'relationship'), u=race]: c1=787.904, c2=226.920
# Query: [Aprime = ('relationship', 'sex'), u=education]: c1=2652.787, c2=2007.198
# Query: [Aprime = ('education', 'sex'), u=relationship]: c1=2804.447, c2=2158.193
# Query: [Aprime = ('education', 'relationship'), u=sex]: c1=787.904, c2=142.143
# Query: [Aprime = ('relationship', 'capital_gain'), u=education]: c1=3260.974, c2=2501.386
# Query: [Aprime = ('education', 'capital_gain'), u=relationship]: c1=6816.634, c2=6056.380
# Query: [Aprime = ('education', 'relationship'), u=capital_gain]: c1=787.904, c2=29.169
# Query: [Aprime = ('relationship', 'capital_loss'), u=education]: c1=3356.425, c2=2580.837
# Query: [Aprime = ('education', 'capital_loss'), u=relationship]: c1=7006.086, c2=6229.832
# Query: [Aprime = ('education', 'relationship'), u=capital_loss]: c1=787.904, c2=9.967
# Query: [Aprime = ('relationship', 'hours_per_week'), u=education]: c1=117.975, c2=95.386
# Query: [Aprime = ('education', 'hours_per_week'), u=relationship]: c1=400.635, c2=377.381
# Query: [Aprime = ('education', 'relationship'), u=hours_per_week]: c1=787.904, c2=766.153
# Query: [Aprime = ('relationship', 'native_country'), u=education]: c1=3031.462, c2=2305.873
# Query: [Aprime = ('education', 'native_country'), u=relationship]: c1=6738.122, c2=6011.868
# Query: [Aprime = ('education', 'relationship'), u=native_country]: c1=787.904, c2=63.834
# Query: [Aprime = ('race', 'sex'), u=education]: c1=8640.042, c2=6371.454
# Query: [Aprime = ('education', 'sex'), u=race]: c1=2804.447, c2=536.463
# Query: [Aprime = ('education', 'race'), u=sex]: c1=6205.160, c2=3936.399
# Query: [Aprime = ('race', 'capital_gain'), u=education]: c1=25405.229, c2=19621.641
# Query: [Aprime = ('education', 'capital_gain'), u=race]: c1=6816.634, c2=1033.650
# Query: [Aprime = ('education', 'race'), u=capital_gain]: c1=6205.160, c2=422.425
# Query: [Aprime = ('race', 'capital_loss'), u=education]: c1=26469.681, c2=20514.093
# Query: [Aprime = ('education', 'capital_loss'), u=race]: c1=7006.086, c2=1051.102
# Query: [Aprime = ('education', 'race'), u=capital_loss]: c1=6205.160, c2=247.223
# Query: [Aprime = ('race', 'hours_per_week'), u=education]: c1=1012.230, c2=682.642
# Query: [Aprime = ('education', 'hours_per_week'), u=race]: c1=400.635, c2=71.651
# Query: [Aprime = ('education', 'race'), u=hours_per_week]: c1=6205.160, c2=5876.409
# Query: [Aprime = ('race', 'native_country'), u=education]: c1=25618.717, c2=19747.129
# Query: [Aprime = ('education', 'native_country'), u=race]: c1=6738.122, c2=867.138
# Query: [Aprime = ('education', 'race'), u=native_country]: c1=6205.160, c2=335.090
# Query: [Aprime = ('sex', 'capital_gain'), u=education]: c1=10146.517, c2=7462.929
# Query: [Aprime = ('education', 'capital_gain'), u=sex]: c1=6816.634, c2=4132.873
# Query: [Aprime = ('education', 'sex'), u=capital_gain]: c1=2804.447, c2=121.712
# Query: [Aprime = ('sex', 'capital_loss'), u=education]: c1=10401.969, c2=7670.380
# Query: [Aprime = ('education', 'capital_loss'), u=sex]: c1=7006.086, c2=4274.325
# Query: [Aprime = ('education', 'sex'), u=capital_loss]: c1=2804.447, c2=70.510
# Query: [Aprime = ('sex', 'hours_per_week'), u=education]: c1=645.518, c2=414.930
# Query: [Aprime = ('education', 'hours_per_week'), u=sex]: c1=400.635, c2=169.874
# Query: [Aprime = ('education', 'sex'), u=hours_per_week]: c1=2804.447, c2=2574.697
# Query: [Aprime = ('sex', 'native_country'), u=education]: c1=9680.005, c2=7084.417
# Query: [Aprime = ('education', 'native_country'), u=sex]: c1=6738.122, c2=4142.361
# Query: [Aprime = ('education', 'sex'), u=native_country]: c1=2804.447, c2=210.377
# Query: [Aprime = ('capital_gain', 'capital_loss'), u=education]: c1=28330.156, c2=21797.568
# Query: [Aprime = ('education', 'capital_loss'), u=capital_gain]: c1=7006.086, c2=474.351
# Query: [Aprime = ('education', 'capital_gain'), u=capital_loss]: c1=6816.634, c2=281.698
# Query: [Aprime = ('capital_gain', 'hours_per_week'), u=education]: c1=1163.705, c2=785.117
# Query: [Aprime = ('education', 'hours_per_week'), u=capital_gain]: c1=400.635, c2=22.900
# Query: [Aprime = ('education', 'capital_gain'), u=hours_per_week]: c1=6816.634, c2=6438.884
# Query: [Aprime = ('capital_gain', 'native_country'), u=education]: c1=26697.192, c2=20408.604
# Query: [Aprime = ('education', 'native_country'), u=capital_gain]: c1=6738.122, c2=450.387
# Query: [Aprime = ('education', 'capital_gain'), u=native_country]: c1=6816.634, c2=529.564
# Query: [Aprime = ('capital_loss', 'hours_per_week'), u=education]: c1=1192.157, c2=800.569
# Query: [Aprime = ('education', 'hours_per_week'), u=capital_loss]: c1=400.635, c2=6.699
# Query: [Aprime = ('education', 'capital_loss'), u=hours_per_week]: c1=7006.086, c2=6615.335
# Query: [Aprime = ('capital_loss', 'native_country'), u=education]: c1=27790.644, c2=21312.056
# Query: [Aprime = ('education', 'native_country'), u=capital_loss]: c1=6738.122, c2=257.186
# Query: [Aprime = ('education', 'capital_loss'), u=native_country]: c1=7006.086, c2=529.016
# Query: [Aprime = ('hours_per_week', 'native_country'), u=education]: c1=1125.193, c2=750.605
# Query: [Aprime = ('education', 'native_country'), u=hours_per_week]: c1=6738.122, c2=6364.372
# Query: [Aprime = ('education', 'hours_per_week'), u=native_country]: c1=400.635, c2=27.565
# Query: [Aprime = ('marital_status', 'occupation'), u=education_num]: c1=465.470, c2=370.087
# Query: [Aprime = ('education_num', 'occupation'), u=marital_status]: c1=870.784, c2=773.866
# Query: [Aprime = ('education_num', 'marital_status'), u=occupation]: c1=1069.665, c2=973.457
# Query: [Aprime = ('marital_status', 'relationship'), u=education_num]: c1=1600.297, c2=1178.915
# Query: [Aprime = ('education_num', 'relationship'), u=marital_status]: c1=789.611, c2=366.693
# Query: [Aprime = ('education_num', 'marital_status'), u=relationship]: c1=1069.665, c2=647.411
# Query: [Aprime = ('marital_status', 'race'), u=education_num]: c1=3795.553, c2=2887.170
# Query: [Aprime = ('education_num', 'race'), u=marital_status]: c1=6206.867, c2=5296.949
# Query: [Aprime = ('education_num', 'marital_status'), u=race]: c1=1069.665, c2=161.681
# Query: [Aprime = ('marital_status', 'sex'), u=education_num]: c1=2670.840, c2=1960.458
# Query: [Aprime = ('education_num', 'sex'), u=marital_status]: c1=2806.155, c2=2094.236
# Query: [Aprime = ('education_num', 'marital_status'), u=sex]: c1=1069.665, c2=358.904
# Query: [Aprime = ('marital_status', 'capital_gain'), u=education_num]: c1=4154.027, c2=3135.645
# Query: [Aprime = ('education_num', 'capital_gain'), u=marital_status]: c1=6818.342, c2=5798.423
# Query: [Aprime = ('education_num', 'marital_status'), u=capital_gain]: c1=1069.665, c2=51.930
# Query: [Aprime = ('marital_status', 'capital_loss'), u=education_num]: c1=4278.479, c2=3238.097
# Query: [Aprime = ('education_num', 'capital_loss'), u=marital_status]: c1=7007.793, c2=5965.875
# Query: [Aprime = ('education_num', 'marital_status'), u=capital_loss]: c1=1069.665, c2=26.728
# Query: [Aprime = ('marital_status', 'hours_per_week'), u=education_num]: c1=100.028, c2=69.646
# Query: [Aprime = ('education_num', 'hours_per_week'), u=marital_status]: c1=402.343, c2=370.424
# Query: [Aprime = ('education_num', 'marital_status'), u=hours_per_week]: c1=1069.665, c2=1039.915
# Query: [Aprime = ('marital_status', 'native_country'), u=education_num]: c1=4160.515, c2=3151.133
# Query: [Aprime = ('education_num', 'native_country'), u=marital_status]: c1=6739.830, c2=5728.911
# Query: [Aprime = ('education_num', 'marital_status'), u=native_country]: c1=1069.665, c2=61.595
# Query: [Aprime = ('occupation', 'relationship'), u=education_num]: c1=248.416, c2=197.034
# Query: [Aprime = ('education_num', 'relationship'), u=occupation]: c1=789.611, c2=737.403
# Query: [Aprime = ('education_num', 'occupation'), u=relationship]: c1=870.784, c2=818.530
# Query: [Aprime = ('occupation', 'race'), u=education_num]: c1=3694.672, c2=2916.289
# Query: [Aprime = ('education_num', 'race'), u=occupation]: c1=6206.867, c2=5427.659
# Query: [Aprime = ('education_num', 'occupation'), u=race]: c1=870.784, c2=92.800
# Query: [Aprime = ('occupation', 'sex'), u=education_num]: c1=222.959, c2=174.577
# Query: [Aprime = ('education_num', 'sex'), u=occupation]: c1=2806.155, c2=2756.947
# Query: [Aprime = ('education_num', 'occupation'), u=sex]: c1=870.784, c2=822.023
# Query: [Aprime = ('occupation', 'capital_gain'), u=education_num]: c1=3791.146, c2=2994.764
# Query: [Aprime = ('education_num', 'capital_gain'), u=occupation]: c1=6818.342, c2=6021.134
# Query: [Aprime = ('education_num', 'occupation'), u=capital_gain]: c1=870.784, c2=75.049
# Query: [Aprime = ('occupation', 'capital_loss'), u=education_num]: c1=3904.598, c2=3081.216
# Query: [Aprime = ('education_num', 'capital_loss'), u=occupation]: c1=7007.793, c2=6183.586
# Query: [Aprime = ('education_num', 'occupation'), u=capital_loss]: c1=870.784, c2=44.847
# Query: [Aprime = ('occupation', 'hours_per_week'), u=education_num]: c1=54.147, c2=45.765
# Good candidate! Denoising more.
# Query: [Aprime = ('occupation', 'hours_per_week'), u=education_num]: c1=54.147, diff=8.873
# Query: [Aprime = ('education_num', 'hours_per_week'), u=occupation]: c1=402.343, c2=393.135
# Good candidate! Denoising more.
# Query: [Aprime = ('education_num', 'hours_per_week'), u=occupation]: c1=402.343, diff=9.084
# Query: [Aprime = ('education_num', 'occupation'), u=hours_per_week]: c1=870.784, c2=863.034
# Good candidate! Denoising more.
# Query: [Aprime = ('education_num', 'occupation'), u=hours_per_week]: c1=870.784, diff=9.295
# Query: [Aprime = ('occupation', 'native_country'), u=education_num]: c1=3685.634, c2=2894.252
# Query: [Aprime = ('education_num', 'native_country'), u=occupation]: c1=6739.830, c2=5947.622
# Query: [Aprime = ('education_num', 'occupation'), u=native_country]: c1=870.784, c2=80.714
# Query: [Aprime = ('relationship', 'race'), u=education_num]: c1=2489.499, c2=1928.116
# Query: [Aprime = ('education_num', 'race'), u=relationship]: c1=6206.867, c2=5644.613
# Query: [Aprime = ('education_num', 'relationship'), u=race]: c1=789.611, c2=228.627
# Query: [Aprime = ('relationship', 'sex'), u=education_num]: c1=2652.787, c2=2007.404
# Query: [Aprime = ('education_num', 'sex'), u=relationship]: c1=2806.155, c2=2159.900
# Query: [Aprime = ('education_num', 'relationship'), u=sex]: c1=789.611, c2=143.850
# Query: [Aprime = ('relationship', 'capital_gain'), u=education_num]: c1=3260.974, c2=2501.591
# Query: [Aprime = ('education_num', 'capital_gain'), u=relationship]: c1=6818.342, c2=6058.087
# Query: [Aprime = ('education_num', 'relationship'), u=capital_gain]: c1=789.611, c2=30.877
# Query: [Aprime = ('relationship', 'capital_loss'), u=education_num]: c1=3356.425, c2=2581.043
# Query: [Aprime = ('education_num', 'capital_loss'), u=relationship]: c1=7007.793, c2=6231.539
# Query: [Aprime = ('education_num', 'relationship'), u=capital_loss]: c1=789.611, c2=11.675
# Query: [Aprime = ('relationship', 'hours_per_week'), u=education_num]: c1=117.975, c2=95.592
# Query: [Aprime = ('education_num', 'hours_per_week'), u=relationship]: c1=402.343, c2=379.088
# Query: [Aprime = ('education_num', 'relationship'), u=hours_per_week]: c1=789.611, c2=767.861
# Query: [Aprime = ('relationship', 'native_country'), u=education_num]: c1=3031.462, c2=2306.079
# Query: [Aprime = ('education_num', 'native_country'), u=relationship]: c1=6739.830, c2=6013.575
# Query: [Aprime = ('education_num', 'relationship'), u=native_country]: c1=789.611, c2=65.542
# Query: [Aprime = ('race', 'sex'), u=education_num]: c1=8640.042, c2=6371.660
# Query: [Aprime = ('education_num', 'sex'), u=race]: c1=2806.155, c2=538.171
# Query: [Aprime = ('education_num', 'race'), u=sex]: c1=6206.867, c2=3938.106
# Query: [Aprime = ('race', 'capital_gain'), u=education_num]: c1=25405.229, c2=19621.847
# Query: [Aprime = ('education_num', 'capital_gain'), u=race]: c1=6818.342, c2=1035.358
# Query: [Aprime = ('education_num', 'race'), u=capital_gain]: c1=6206.867, c2=424.132
# Query: [Aprime = ('race', 'capital_loss'), u=education_num]: c1=26469.681, c2=20514.298
# Query: [Aprime = ('education_num', 'capital_loss'), u=race]: c1=7007.793, c2=1052.810
# Query: [Aprime = ('education_num', 'race'), u=capital_loss]: c1=6206.867, c2=248.930
# Query: [Aprime = ('race', 'hours_per_week'), u=education_num]: c1=1012.230, c2=682.848
# Query: [Aprime = ('education_num', 'hours_per_week'), u=race]: c1=402.343, c2=73.359
# Query: [Aprime = ('education_num', 'race'), u=hours_per_week]: c1=6206.867, c2=5878.116
# Query: [Aprime = ('race', 'native_country'), u=education_num]: c1=25618.717, c2=19747.335
# Query: [Aprime = ('education_num', 'native_country'), u=race]: c1=6739.830, c2=868.846
# Query: [Aprime = ('education_num', 'race'), u=native_country]: c1=6206.867, c2=336.797
# Query: [Aprime = ('sex', 'capital_gain'), u=education_num]: c1=10146.517, c2=7463.134
# Query: [Aprime = ('education_num', 'capital_gain'), u=sex]: c1=6818.342, c2=4134.581
# Query: [Aprime = ('education_num', 'sex'), u=capital_gain]: c1=2806.155, c2=123.420
# Query: [Aprime = ('sex', 'capital_loss'), u=education_num]: c1=10401.969, c2=7670.586
# Query: [Aprime = ('education_num', 'capital_loss'), u=sex]: c1=7007.793, c2=4276.032
# Query: [Aprime = ('education_num', 'sex'), u=capital_loss]: c1=2806.155, c2=72.218
# Query: [Aprime = ('sex', 'hours_per_week'), u=education_num]: c1=645.518, c2=415.135
# Query: [Aprime = ('education_num', 'hours_per_week'), u=sex]: c1=402.343, c2=171.582
# Query: [Aprime = ('education_num', 'sex'), u=hours_per_week]: c1=2806.155, c2=2576.404
# Query: [Aprime = ('sex', 'native_country'), u=education_num]: c1=9680.005, c2=7084.622
# Query: [Aprime = ('education_num', 'native_country'), u=sex]: c1=6739.830, c2=4144.069
# Query: [Aprime = ('education_num', 'sex'), u=native_country]: c1=2806.155, c2=212.085
# Query: [Aprime = ('capital_gain', 'capital_loss'), u=education_num]: c1=28330.156, c2=21797.773
# Query: [Aprime = ('education_num', 'capital_loss'), u=capital_gain]: c1=7007.793, c2=476.059
# Query: [Aprime = ('education_num', 'capital_gain'), u=capital_loss]: c1=6818.342, c2=283.405
# Query: [Aprime = ('capital_gain', 'hours_per_week'), u=education_num]: c1=1163.705, c2=785.322
# Query: [Aprime = ('education_num', 'hours_per_week'), u=capital_gain]: c1=402.343, c2=24.608
# Query: [Aprime = ('education_num', 'capital_gain'), u=hours_per_week]: c1=6818.342, c2=6440.591
# Query: [Aprime = ('capital_gain', 'native_country'), u=education_num]: c1=26697.192, c2=20408.809
# Query: [Aprime = ('education_num', 'native_country'), u=capital_gain]: c1=6739.830, c2=452.095
# Query: [Aprime = ('education_num', 'capital_gain'), u=native_country]: c1=6818.342, c2=531.272
# Query: [Aprime = ('capital_loss', 'hours_per_week'), u=education_num]: c1=1192.157, c2=800.774
# Query: [Aprime = ('education_num', 'hours_per_week'), u=capital_loss]: c1=402.343, c2=8.406
# Query: [Aprime = ('education_num', 'capital_loss'), u=hours_per_week]: c1=7007.793, c2=6617.043
# Query: [Aprime = ('capital_loss', 'native_country'), u=education_num]: c1=27790.644, c2=21312.261
# Query: [Aprime = ('education_num', 'native_country'), u=capital_loss]: c1=6739.830, c2=258.893
# Query: [Aprime = ('education_num', 'capital_loss'), u=native_country]: c1=7007.793, c2=530.724
# Query: [Aprime = ('hours_per_week', 'native_country'), u=education_num]: c1=1125.193, c2=750.810
# Query: [Aprime = ('education_num', 'native_country'), u=hours_per_week]: c1=6739.830, c2=6366.079
# Query: [Aprime = ('education_num', 'hours_per_week'), u=native_country]: c1=402.343, c2=29.273
# Query: [Aprime = ('occupation', 'relationship'), u=marital_status]: c1=248.416, c2=130.498
# Query: [Aprime = ('marital_status', 'relationship'), u=occupation]: c1=1600.297, c2=1483.089
# Query: [Aprime = ('marital_status', 'occupation'), u=relationship]: c1=465.470, c2=348.216
# Query: [Aprime = ('occupation', 'race'), u=marital_status]: c1=3694.672, c2=3272.753
# Query: [Aprime = ('marital_status', 'race'), u=occupation]: c1=3795.553, c2=3374.345
# Query: [Aprime = ('marital_status', 'occupation'), u=race]: c1=465.470, c2=45.486
# Query: [Aprime = ('occupation', 'sex'), u=marital_status]: c1=222.959, c2=145.041
# Query: [Aprime = ('marital_status', 'sex'), u=occupation]: c1=2670.840, c2=2593.632
# Query: [Aprime = ('marital_status', 'occupation'), u=sex]: c1=465.470, c2=388.709
# Query: [Aprime = ('occupation', 'capital_gain'), u=marital_status]: c1=3791.146, c2=3355.228
# Query: [Aprime = ('marital_status', 'capital_gain'), u=occupation]: c1=4154.027, c2=3718.820
# Query: [Aprime = ('marital_status', 'occupation'), u=capital_gain]: c1=465.470, c2=31.735
# Query: [Aprime = ('occupation', 'capital_loss'), u=marital_status]: c1=3904.598, c2=3459.680
# Query: [Aprime = ('marital_status', 'capital_loss'), u=occupation]: c1=4278.479, c2=3834.271
# Query: [Aprime = ('marital_status', 'occupation'), u=capital_loss]: c1=465.470, c2=19.533
# Query: [Aprime = ('occupation', 'hours_per_week'), u=marital_status]: c1=54.147, c2=47.229
# Good candidate! Denoising more.
# ...
# Query: [Aprime = ('education', 'education_num', 'hours_per_week'), u=capital_gain]: c1=401.625, c2=23.890
# Query: [Aprime = ('education', 'education_num', 'capital_gain'), u=hours_per_week]: c1=6817.624, c2=6439.873
# Query: [Aprime = ('education_num', 'capital_gain', 'native_country'), u=education]: c1=6288.182, c2=-1.000
# Query: [Aprime = ('education', 'capital_gain', 'native_country'), u=education_num]: c1=6286.474, c2=-1.000
# Query: [Aprime = ('education', 'education_num', 'native_country'), u=capital_gain]: c1=6739.112, c2=451.377
# Query: [Aprime = ('education', 'education_num', 'capital_gain'), u=native_country]: c1=6817.624, c2=530.554
# Query: [Aprime = ('education_num', 'capital_loss', 'hours_per_week'), u=education]: c1=396.146, c2=-1.000
# Query: [Aprime = ('education', 'capital_loss', 'hours_per_week'), u=education_num]: c1=394.439, c2=-1.000
# Query: [Aprime = ('education', 'education_num', 'hours_per_week'), u=capital_loss]: c1=401.625, c2=7.688
# Query: [Aprime = ('education', 'education_num', 'capital_loss'), u=hours_per_week]: c1=7007.076, c2=6616.325
# Query: [Aprime = ('education_num', 'capital_loss', 'native_country'), u=education]: c1=6479.633, c2=-1.000
# Query: [Aprime = ('education', 'capital_loss', 'native_country'), u=education_num]: c1=6477.926, c2=-1.000
# Query: [Aprime = ('education', 'education_num', 'native_country'), u=capital_loss]: c1=6739.112, c2=258.175
# Query: [Aprime = ('education', 'education_num', 'capital_loss'), u=native_country]: c1=7007.076, c2=530.006
# Query: [Aprime = ('education_num', 'hours_per_week', 'native_country'), u=education]: c1=377.182, c2=-1.000
# Query: [Aprime = ('education', 'hours_per_week', 'native_country'), u=education_num]: c1=375.475, c2=-1.000
# Query: [Aprime = ('education', 'education_num', 'native_country'), u=hours_per_week]: c1=6739.112, c2=6365.361
# Query: [Aprime = ('education', 'education_num', 'hours_per_week'), u=native_country]: c1=401.625, c2=28.555
# Query: [Aprime = ('marital_status', 'occupation', 'relationship'), u=education]: c1=118.091, c2=93.503
# Query: [Aprime = ('education', 'occupation', 'relationship'), u=marital_status]: c1=52.698, c2=26.780
# Query: [Aprime = ('education', 'marital_status', 'relationship'), u=occupation]: c1=420.579, c2=395.372
# Query: [Aprime = ('education', 'marital_status', 'occupation'), u=relationship]: c1=96.752, c2=71.498
# Query: [Aprime = ('marital_status', 'occupation', 'race'), u=education]: c1=421.347, c2=331.759
# Query: [Aprime = ('education', 'occupation', 'race'), u=marital_status]: c1=778.954, c2=688.036
# Query: [Aprime = ('education', 'marital_status', 'race'), u=occupation]: c1=906.835, c2=816.627
# Query: [Aprime = ('education', 'marital_status', 'occupation'), u=race]: c1=96.752, c2=7.768
# Query: [Aprime = ('marital_status', 'occupation', 'sex'), u=education]: c1=77.635, c2=63.047
# Query: [Aprime = ('education', 'occupation', 'sex'), u=marital_status]: c1=49.242, c2=33.323
# Query: [Aprime = ('education', 'marital_status', 'sex'), u=occupation]: c1=709.123, c2=693.915
# Query: [Aprime = ('education', 'marital_status', 'occupation'), u=sex]: c1=96.752, c2=81.991
# Query: [Aprime = ('marital_status', 'occupation', 'capital_gain'), u=education]: c1=435.822, c2=346.234
# Query: [Aprime = ('education', 'occupation', 'capital_gain'), u=marital_status]: c1=797.429, c2=706.510
# Query: [Aprime = ('education', 'marital_status', 'capital_gain'), u=occupation]: c1=1017.310, c2=927.102
# Query: [Aprime = ('education', 'marital_status', 'occupation'), u=capital_gain]: c1=96.752, c2=8.017
# Query: [Aprime = ('marital_status', 'occupation', 'capital_loss'), u=education]: c1=446.274, c2=352.685
# Query: [Aprime = ('education', 'occupation', 'capital_loss'), u=marital_status]: c1=825.880, c2=730.962
# Query: [Aprime = ('education', 'marital_status', 'capital_loss'), u=occupation]: c1=1040.761, c2=946.554
# Query: [Aprime = ('education', 'marital_status', 'occupation'), u=capital_loss]: c1=96.752, c2=-1.000
# Query: [Aprime = ('marital_status', 'occupation', 'hours_per_week'), u=education]: c1=9.823, c2=-1.000
# Query: [Aprime = ('education', 'occupation', 'hours_per_week'), u=marital_status]: c1=12.430, c2=9.511
# Good candidate! Denoising more.
# Query: [Aprime = ('education', 'occupation', 'hours_per_week'), u=marital_status]: c1=12.430, diff=1.981
# Query: [Aprime = ('education', 'marital_status', 'hours_per_week'), u=occupation]: c1=32.311, c2=30.103
# Good candidate! Denoising more.
# Query: [Aprime = ('education', 'marital_status', 'hours_per_week'), u=occupation]: c1=32.311, diff=2.084
# Query: [Aprime = ('education', 'marital_status', 'occupation'), u=hours_per_week]: c1=96.752, c2=96.002
# Good candidate! Denoising more.
# Query: [Aprime = ('education', 'marital_status', 'occupation'), u=hours_per_week]: c1=96.752, diff=2.295
# Query: [Aprime = ('marital_status', 'occupation', 'native_country'), u=education]: c1=438.310, c2=347.722
# Query: [Aprime = ('education', 'occupation', 'native_country'), u=marital_status]: c1=791.917, c2=699.998
# Query: [Aprime = ('education', 'marital_status', 'native_country'), u=occupation]: c1=1007.798, c2=916.590
# Query: [Aprime = ('education', 'marital_status', 'occupation'), u=native_country]: c1=96.752, c2=7.682
# Query: [Aprime = ('marital_status', 'relationship', 'race'), u=education]: c1=1308.174, c2=974.586
# Query: [Aprime = ('education', 'relationship', 'race'), u=marital_status]: c1=559.781, c2=224.863
# Query: [Aprime = ('education', 'marital_status', 'race'), u=relationship]: c1=906.835, c2=572.581
# Query: [Aprime = ('education', 'marital_status', 'relationship'), u=race]: c1=420.579, c2=87.595
# Query: [Aprime = ('marital_status', 'relationship', 'sex'), u=education]: c1=1277.462, c2=923.874
# Query: [Aprime = ('education', 'relationship', 'sex'), u=marital_status]: c1=644.069, c2=289.151
# Query: [Aprime = ('education', 'marital_status', 'sex'), u=relationship]: c1=709.123, c2=354.868
# Query: [Aprime = ('education', 'marital_status', 'relationship'), u=sex]: c1=420.579, c2=66.818
# Query: [Aprime = ('marital_status', 'relationship', 'capital_gain'), u=education]: c1=1499.649, c2=1093.061
# Query: [Aprime = ('education', 'relationship', 'capital_gain'), u=marital_status]: c1=758.256, c2=350.338
# Query: [Aprime = ('education', 'marital_status', 'capital_gain'), u=relationship]: c1=1017.310, c2=610.056
# Query: [Aprime = ('education', 'marital_status', 'relationship'), u=capital_gain]: c1=420.579, c2=14.845
# Query: [Aprime = ('marital_status', 'relationship', 'capital_loss'), u=education]: c1=1553.101, c2=1138.513
# Query: [Aprime = ('education', 'relationship', 'capital_loss'), u=marital_status]: c1=775.708, c2=359.789
# Query: [Aprime = ('education', 'marital_status', 'capital_loss'), u=relationship]: c1=1040.761, c2=625.507
# Query: [Aprime = ('education', 'marital_status', 'relationship'), u=capital_loss]: c1=420.579, c2=3.643
# Query: [Aprime = ('marital_status', 'relationship', 'hours_per_week'), u=education]: c1=32.650, c2=22.062
# Query: [Aprime = ('education', 'relationship', 'hours_per_week'), u=marital_status]: c1=24.257, c2=12.339
# Query: [Aprime = ('education', 'marital_status', 'hours_per_week'), u=relationship]: c1=32.311, c2=21.056
# Query: [Aprime = ('education', 'marital_status', 'relationship'), u=hours_per_week]: c1=420.579, c2=410.829
# Good candidate! Denoising more.
# Query: [Aprime = ('education', 'marital_status', 'relationship'), u=hours_per_week]: c1=420.579, diff=11.295
# Query: [Aprime = ('marital_status', 'relationship', 'native_country'), u=education]: c1=1480.137, c2=1085.549
# Query: [Aprime = ('education', 'relationship', 'native_country'), u=marital_status]: c1=723.744, c2=327.826
# Query: [Aprime = ('education', 'marital_status', 'native_country'), u=relationship]: c1=1007.798, c2=612.543
# Query: [Aprime = ('education', 'marital_status', 'relationship'), u=native_country]: c1=420.579, c2=27.510
# Query: [Aprime = ('marital_status', 'race', 'sex'), u=education]: c1=2223.718, c2=1640.129
# Query: [Aprime = ('education', 'race', 'sex'), u=marital_status]: c1=2266.324, c2=1681.406
# Query: [Aprime = ('education', 'marital_status', 'sex'), u=race]: c1=709.123, c2=126.139
# Query: [Aprime = ('education', 'marital_status', 'race'), u=sex]: c1=906.835, c2=323.074
# Query: [Aprime = ('marital_status', 'race', 'capital_gain'), u=education]: c1=3539.905, c2=2678.317
# Query: [Aprime = ('education', 'race', 'capital_gain'), u=marital_status]: c1=5781.511, c2=4918.593
# Query: [Aprime = ('education', 'marital_status', 'capital_gain'), u=race]: c1=1017.310, c2=156.326
# Query: [Aprime = ('education', 'marital_status', 'race'), u=capital_gain]: c1=906.835, c2=46.100
# Query: [Aprime = ('marital_status', 'race', 'capital_loss'), u=education]: c1=3649.356, c2=2767.768
# Query: [Aprime = ('education', 'race', 'capital_loss'), u=marital_status]: c1=5954.963, c2=5072.045
# Query: [Aprime = ('education', 'marital_status', 'capital_loss'), u=race]: c1=1040.761, c2=159.778
# Query: [Aprime = ('education', 'marital_status', 'race'), u=capital_loss]: c1=906.835, c2=22.898
# Query: [Aprime = ('marital_status', 'race', 'hours_per_week'), u=education]: c1=81.906, c2=55.318
# Query: [Aprime = ('education', 'race', 'hours_per_week'), u=marital_status]: c1=330.512, c2=302.594
# Query: [Aprime = ('education', 'marital_status', 'hours_per_week'), u=race]: c1=32.311, c2=-1.000
# Query: [Aprime = ('education', 'marital_status', 'race'), u=hours_per_week]: c1=906.835, c2=881.084
# Query: [Aprime = ('marital_status', 'race', 'native_country'), u=education]: c1=3600.393, c2=2735.805
# Query: [Aprime = ('education', 'race', 'native_country'), u=marital_status]: c1=5868.999, c2=5003.081
# Query: [Aprime = ('education', 'marital_status', 'native_country'), u=race]: c1=1007.798, c2=143.814
# Query: [Aprime = ('education', 'marital_status', 'race'), u=native_country]: c1=906.835, c2=43.765
# Query: [Aprime = ('marital_status', 'sex', 'capital_gain'), u=education]: c1=2534.192, c2=1847.604
# Query: [Aprime = ('education', 'sex', 'capital_gain'), u=marital_status]: c1=2681.799, c2=1993.881
# Query: [Aprime = ('education', 'marital_status', 'capital_gain'), u=sex]: c1=1017.310, c2=330.549
# Query: [Aprime = ('education', 'marital_status', 'sex'), u=capital_gain]: c1=709.123, c2=23.388
# Query: [Aprime = ('marital_status', 'sex', 'capital_loss'), u=education]: c1=2589.644, c2=1894.056
# Query: [Aprime = ('education', 'sex', 'capital_loss'), u=marital_status]: c1=2731.251, c2=2034.333
# Query: [Aprime = ('education', 'marital_status', 'capital_loss'), u=sex]: c1=1040.761, c2=345.000
# Query: [Aprime = ('education', 'marital_status', 'sex'), u=capital_loss]: c1=709.123, c2=11.186
# Query: [Aprime = ('marital_status', 'sex', 'hours_per_week'), u=education]: c1=69.193, c2=42.605
# Query: [Aprime = ('education', 'sex', 'hours_per_week'), u=marital_status]: c1=231.800, c2=203.882
# Query: [Aprime = ('education', 'marital_status', 'hours_per_week'), u=sex]: c1=32.311, c2=-1.000
# Query: [Aprime = ('education', 'marital_status', 'sex'), u=hours_per_week]: c1=709.123, c2=683.372
# Query: [Aprime = ('marital_status', 'sex', 'native_country'), u=education]: c1=2490.680, c2=1819.092
# Query: [Aprime = ('education', 'sex', 'native_country'), u=marital_status]: c1=2593.287, c2=1920.369
# Query: [Aprime = ('education', 'marital_status', 'native_country'), u=sex]: c1=1007.798, c2=336.037
# Query: [Aprime = ('education', 'marital_status', 'sex'), u=native_country]: c1=709.123, c2=39.053
# Query: [Aprime = ('marital_status', 'capital_gain', 'capital_loss'), u=education]: c1=3989.831, c2=2999.243
# Query: [Aprime = ('education', 'capital_gain', 'capital_loss'), u=marital_status]: c1=6532.438, c2=5540.520
# Query: [Aprime = ('education', 'marital_status', 'capital_loss'), u=capital_gain]: c1=1040.761, c2=51.027
# Query: [Aprime = ('education', 'marital_status', 'capital_gain'), u=capital_loss]: c1=1017.310, c2=24.373
# Query: [Aprime = ('marital_status', 'capital_gain', 'hours_per_week'), u=education]: c1=95.380, c2=66.792
# Query: [Aprime = ('education', 'capital_gain', 'hours_per_week'), u=marital_status]: c1=379.987, c2=350.069
# Query: [Aprime = ('education', 'marital_status', 'hours_per_week'), u=capital_gain]: c1=32.311, c2=-1.000
# Query: [Aprime = ('education', 'marital_status', 'capital_gain'), u=hours_per_week]: c1=1017.310, c2=989.559
# Query: [Aprime = ('marital_status', 'capital_gain', 'native_country'), u=education]: c1=3888.867, c2=2925.279
# Query: [Aprime = ('education', 'capital_gain', 'native_country'), u=marital_status]: c1=6286.474, c2=5321.556
# Query: [Aprime = ('education', 'marital_status', 'native_country'), u=capital_gain]: c1=1007.798, c2=45.063
# Query: [Aprime = ('education', 'marital_status', 'capital_gain'), u=native_country]: c1=1017.310, c2=55.240
# Query: [Aprime = ('marital_status', 'capital_loss', 'hours_per_week'), u=education]: c1=100.832, c2=70.244
# Query: [Aprime = ('education', 'capital_loss', 'hours_per_week'), u=marital_status]: c1=394.439, c2=362.521
# Query: [Aprime = ('education', 'marital_status', 'hours_per_week'), u=capital_loss]: c1=32.311, c2=-1.000
# Query: [Aprime = ('education', 'marital_status', 'capital_loss'), u=hours_per_week]: c1=1040.761, c2=1011.011
# Query: [Aprime = ('marital_status', 'capital_loss', 'native_country'), u=education]: c1=4004.319, c2=3021.731
# Query: [Aprime = ('education', 'capital_loss', 'native_country'), u=marital_status]: c1=6477.926, c2=5494.008
# Query: [Aprime = ('education', 'marital_status', 'native_country'), u=capital_loss]: c1=1007.798, c2=22.861
# Query: [Aprime = ('education', 'marital_status', 'capital_loss'), u=native_country]: c1=1040.761, c2=59.692
# Query: [Aprime = ('marital_status', 'hours_per_week', 'native_country'), u=education]: c1=92.868, c2=64.280
# Query: [Aprime = ('education', 'hours_per_week', 'native_country'), u=marital_status]: c1=375.475, c2=345.557
# Query: [Aprime = ('education', 'marital_status', 'native_country'), u=hours_per_week]: c1=1007.798, c2=980.047
# Query: [Aprime = ('education', 'marital_status', 'hours_per_week'), u=native_country]: c1=32.311, c2=-1.000
# Query: [Aprime = ('occupation', 'relationship', 'race'), u=education]: c1=204.293, c2=158.705
# Query: [Aprime = ('education', 'relationship', 'race'), u=occupation]: c1=559.781, c2=513.573
# Query: [Aprime = ('education', 'occupation', 'race'), u=relationship]: c1=778.954, c2=732.700
# Query: [Aprime = ('education', 'occupation', 'relationship'), u=race]: c1=52.698, c2=7.714
# Query: [Aprime = ('occupation', 'relationship', 'sex'), u=education]: c1=76.581, c2=61.993
# Query: [Aprime = ('education', 'relationship', 'sex'), u=occupation]: c1=644.069, c2=628.861
# Query: [Aprime = ('education', 'occupation', 'sex'), u=relationship]: c1=49.242, c2=33.987
# Query: [Aprime = ('education', 'occupation', 'relationship'), u=sex]: c1=52.698, c2=37.937
# Query: [Aprime = ('occupation', 'relationship', 'capital_gain'), u=education]: c1=229.768, c2=180.180
# Query: [Aprime = ('education', 'relationship', 'capital_gain'), u=occupation]: c1=758.256, c2=708.048
# Query: [Aprime = ('education', 'occupation', 'capital_gain'), u=relationship]: c1=797.429, c2=747.174
# Query: [Aprime = ('education', 'occupation', 'relationship'), u=capital_gain]: c1=52.698, c2=-1.000
# Query: [Aprime = ('occupation', 'relationship', 'capital_loss'), u=education]: c1=244.220, c2=193.632
# Query: [Aprime = ('education', 'relationship', 'capital_loss'), u=occupation]: c1=775.708, c2=724.500
# Query: [Aprime = ('education', 'occupation', 'capital_loss'), u=relationship]: c1=825.880, c2=774.626
# Query: [Aprime = ('education', 'occupation', 'relationship'), u=capital_loss]: c1=52.698, c2=-1.000
# Query: [Aprime = ('occupation', 'relationship', 'hours_per_week'), u=education]: c1=-1.000, c2=-1.000
# Good candidate! Denoising more.
# Query: [Aprime = ('occupation', 'relationship', 'hours_per_week'), u=education]: c1=-1.000, diff=0.000
# Query: [Aprime = ('education', 'relationship', 'hours_per_week'), u=occupation]: c1=24.257, c2=23.049
# Good candidate! Denoising more.
# Query: [Aprime = ('education', 'relationship', 'hours_per_week'), u=occupation]: c1=24.257, diff=1.084
# Found!

# %% [markdown]
# Step 2. We now perform a difference attack with the various ages. The idea is to count if $Age \neq x$ for $(A' = a^{Deborah})$ and $(A' = a^{Deborah}\land U \neq u^{Deborah})$. Since we know that $U$ is a discriminative condition, Deborah is the only user who can be in the first query and not the other. So, if the difference between the two counts is 1, it means Deborah was included by $Age \neq x$, and her age thus isn't $x$.

# %%
# We first define all the queries for Deborah and (Aprime, u) -- see exercise 2 step 4.
query1 = ' and '.join( '%s = %s' % (c, Deborah[c]) for c in Aprime)
query2s = []
for x in range(20):
    q2 = query1 + ' and %s <> (%s+%d-%d)' % (u, Deborah[u], x, x)
    query2s.append(q2)


# Perform the queries with the various ages.
for age in range(10, 100):

    age_condition = ' and age <> %d' % age

    # Difference query: the result is the true value + N(0,2).
    samples = [(query_2(query1 + age_condition) - query_2(q + age_condition)) for q in query2s]
    print('[Age = %d] difference: %.3f' % (age, np.mean(samples)))
# Out:
# [Age = 10] difference: 1.041
# [Age = 11] difference: 1.041
# [Age = 12] difference: 1.041
# [Age = 13] difference: 1.041
# [Age = 14] difference: 1.041
# [Age = 15] difference: 1.041
# [Age = 16] difference: 1.041
# [Age = 17] difference: 1.041
# [Age = 18] difference: 1.041
# [Age = 19] difference: 1.041
# [Age = 20] difference: 1.041
# [Age = 21] difference: 1.041
# [Age = 22] difference: 1.041
# [Age = 23] difference: 1.041
# [Age = 24] difference: 1.041
# [Age = 25] difference: 1.041
# [Age = 26] difference: 1.041
# [Age = 27] difference: 1.041
# [Age = 28] difference: 1.041
# [Age = 29] difference: 1.041
# [Age = 30] difference: 1.041
# [Age = 31] difference: 0.041
# [Age = 32] difference: 1.041
# [Age = 33] difference: 1.041
# [Age = 34] difference: 1.041
# [Age = 35] difference: 1.041
# [Age = 36] difference: 1.041
# [Age = 37] difference: 1.041
# [Age = 38] difference: 1.041
# [Age = 39] difference: 1.041
# [Age = 40] difference: 1.041
# [Age = 41] difference: 1.041
# [Age = 42] difference: 1.041
# [Age = 43] difference: 1.041
# [Age = 44] difference: 1.041
# [Age = 45] difference: 1.041
# [Age = 46] difference: 1.041
# [Age = 47] difference: 1.041
# [Age = 48] difference: 1.041
# [Age = 49] difference: 1.041
# [Age = 50] difference: 1.041
# [Age = 51] difference: 1.041
# [Age = 52] difference: 1.041
# [Age = 53] difference: 1.041
# [Age = 54] difference: 1.041
# [Age = 55] difference: 1.041
# [Age = 56] difference: 1.041
# [Age = 57] difference: 1.041
# [Age = 58] difference: 1.041
# [Age = 59] difference: 1.041
# [Age = 60] difference: 1.041
# [Age = 61] difference: 1.041
# [Age = 62] difference: 1.041
# [Age = 63] difference: 1.041
# [Age = 64] difference: 1.041
# [Age = 65] difference: 1.041
# [Age = 66] difference: 1.041
# [Age = 67] difference: 1.041
# [Age = 68] difference: 1.041
# [Age = 69] difference: 1.041
# [Age = 70] difference: 1.041
# [Age = 71] difference: 1.041
# [Age = 72] difference: 1.041
# [Age = 73] difference: 1.041
# [Age = 74] difference: 1.041
# [Age = 75] difference: 1.041
# [Age = 76] difference: 1.041
# [Age = 77] difference: 1.041
# [Age = 78] difference: 1.041
# [Age = 79] difference: 1.041
# [Age = 80] difference: 1.041
# [Age = 81] difference: 1.041
# [Age = 82] difference: 1.041
# [Age = 83] difference: 1.041
# [Age = 84] difference: 1.041
# [Age = 85] difference: 1.041
# [Age = 86] difference: 1.041
# [Age = 87] difference: 1.041
# [Age = 88] difference: 1.041
# [Age = 89] difference: 1.041
# [Age = 90] difference: 1.041
# [Age = 91] difference: 1.041
# [Age = 92] difference: 1.041
# [Age = 93] difference: 1.041
# [Age = 94] difference: 1.041
# [Age = 95] difference: 1.041
# [Age = 96] difference: 1.041
# [Age = 97] difference: 1.041
# [Age = 98] difference: 1.041
# [Age = 99] difference: 1.041

# %% [markdown]
# There you have it: the answer is **31**.
#
# Now, you may have noticed that the noises observed here are _identical_ : we get the same result (+- 1) for all queries when age changes. Why is that the case? Can you then devise a better attack that exploits this fact?
